# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences

from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.layers import Bidirectional
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler


from sklearn import linear_model 
from sklearn.metrics import mean_absolute_error
sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('Equites_Historical_NonAdjusted_Prices.csv', usecols=['Industry Group', 'Symbol', 'Company Name', 'Date', 'Open', 'High',
       'Low', 'Close', 'Change', '% Change', 'Volume Traded','Value Traded (SAR)', 'No. of Trades'])

# %%
df.Date = pd.to_datetime(df.Date, dayfirst=True)

# %%
df.sort_values('Date',inplace=True)

# %%
df['Company Name'].unique()[65]
# Out:
# 'Saudi Advanced Industries Co.'

# %%
df['Company Name'].groupby(df['Industry Group']).value_counts()
# Out:
# Industry Group                  Company Name
# Banks                           Al Rajhi Bank                                          2722
#                                 Alinma Bank                                            2722
#                                 Arab National Bank                                     2722
#                                 Bank Albilad                                           2722
#                                 Bank Aljazira                                          2722
#                                 Banque Saudi Fransi                                    2722
#                                 Riyad Bank                                             2722
#                                 Samba Financial Group                                  2722
#                                 Saudi British Bank                                     2722
#                                 Saudi Investment Bank                                  2722
#                                 National Commercial Bank                               1262
# Capital Goods                   Al-Ahsa Development Co.                                2722
#                                 Al-Babtain Power and Telecommunication Co.             2722
#                                 Astra Industrial Group                                 2722
#                                 Middle East Specialized Cables Co.                     2722
#                                 Saudi Arabian Amiantit Co.                             2722
#                                 Saudi Cable Co.                                        2722
#                                 Saudi Ceramic Co.                                      2722
#                                 Saudi Industrial Export Co.                            2722
#                                 Saudi Vitrified Clay Pipes Co.                         2722
#                                 Abdullah A. M. Al-Khodari Sons Co.                     2268
#                                 Mohammad Al Mojil Group                                2087
#                                 Bawan Co.                                              1482
#                                 Electrical Industries Co.                              1245
# Commercial & Professional Svc   Saudi Printing and Packaging Co.                       2722
#                                 Saudi Airlines Catering Co.                            1839
#                                 Maharah Human Resources Co.                             112
# Consumer Durables & Apparel     Al Abdullatif Industrial Investment Co.                2722
#                                 Fitaihi Holding Group                                  2722
#                                 Saudi Industrial Development Co.                       2722
#                                                                                        ...
# Real Estate Mgmt & Dev't        Emaar The Economic City                                2722
#                                 Jabal Omar Development Co.                             2722
#                                 Makkah Construction and Development Co.                2722
#                                 Red Sea International Co.                              2722
#                                 Saudi Real Estate Co.                                  2722
#                                 Taiba Investments Co.                                  2722
#                                 Knowledge Economic City                                2315
#                                 Alandalus Property Co.                                  968
#                                 Arabian Centres Co.                                     126
# Retailing                       Fawaz Abdulaziz Alhokair Co.                           2722
#                                 Jarir Marketing Co.                                    2722
#                                 Saudi Automotive Services Co.                          2722
#                                 Al Hassan Ghazi Ibrahim Shaker Co.                     2375
#                                 United Electronics Co.                                 1981
#                                 Saudi Company for Hardware                             1134
#                                 Abdullah Saad Mohammed Abo Moati for Bookstores Co.     686
# Software & Services             Al Moammar Information Systems Co.                      146
# Tadawul All Share Index (TASI)  Alawwal Bank                                           2610
# 2747         2.448475e+07            784
# 29815        1.450239e+08           4536
# 29861        4.513672e+07           1401
# 13523        7.855653e+07           2070
# 25           3.568464e+07           1175
# 18968        2.773024e+07           1078
# 16245        7.080241e+07           1336
# 21683        4.395077e+08           6031
# 10801        1.868539e+07            459
# 8156         1.734346e+05             23
# 24405        1.248180e+07           1048
# 26           3.671371e+07            852
# 29816        1.507655e+08           4950
# 29862        4.217433e+07            989
# 13524        5.115902e+07           1369
# 21684        3.284859e+08           4586
# 18969        4.299681e+07           1233
# 16246        1.582016e+08            924
# 2748         1.999186e+07            815
# 8157         1.988629e+06             35
# 10802        2.010179e+07            522
# 24406        8.675895e+06            681
#
# [28482 rows x 13 columns]

# %%
Riyad_Bank = df[df['Company Name']== 'Saudi Electricity Co.']

# %%
Riyadhb_for_model = Riyad_Bank[['Date','Open', 'High', 'Low',
       'Close', 'Change', '% Change']]

# %%
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaled = scaler.fit_transform(Riyad_Bank[['Open', 'High', 'Low',
#        'Close', 'Change']])

# %%
# scaled_df = pd.DataFrame()

# %%
Riyadhb_for_model
# Out:
#              Date   Open   High    Low  Close  Change  % Change
# 317526 2009-01-03   9.30   9.45   9.25   9.35    0.10      1.08
# 317528 2009-01-04   9.35   9.40   9.30   9.40    0.05      0.53
# 317529 2009-01-05   9.40   9.55   9.40   9.45    0.05      0.53
# 317530 2009-01-06   9.50   9.60   9.45   9.55    0.10      1.05
# 317532 2009-01-07   9.55   9.85   9.55   9.80    0.25      2.61
# 317533 2009-01-10   9.60   9.60   9.45   9.50   -0.30     -3.06
# 317535 2009-01-11   9.55   9.70   9.55   9.55    0.05      0.52
# 317536 2009-01-12   9.55   9.60   9.50   9.55    0.00      0.00
# 317537 2009-01-13   9.50   9.55   9.50   9.50   -0.05     -0.52
# 317539 2009-01-14   9.50   9.50   9.45   9.45   -0.05     -0.52
# 317540 2009-01-17   9.45   9.45   9.30   9.35   -0.10     -1.05
# 317542 2009-01-18   9.30   9.40   9.30   9.35    0.00      0.00
# 317543 2009-01-19   9.40   9.40   9.30   9.35    0.00      0.00
# 317545 2009-01-20   9.25   9.35   9.20   9.35    0.00      0.00
# 317546 2009-01-21   9.25   9.30   9.10   9.25   -0.10     -1.06
# 317547 2009-01-24   9.30   9.45   9.30   9.45    0.20      2.16
# 317421 2009-01-25   9.45   9.45   9.30   9.30   -0.15     -1.58
# 317422 2009-01-26   9.35   9.40   9.30   9.35    0.05      0.53
# 317424 2009-01-27   9.35   9.45   9.30   9.40    0.05      0.53
# 317425 2009-01-28   9.40   9.50   9.40   9.45    0.05      0.53
# 317427 2009-01-31   9.45   9.55   9.45   9.45    0.00      0.00
# 317428 2009-02-01   9.50   9.55   9.45   9.55    0.10      1.05
# 317429 2009-02-02   9.55   9.55   9.45   9.55    0.00      0.00
# 317431 2009-02-03   9.55   9.55   9.45   9.55    0.00      0.00
# 317432 2009-02-04   9.55   9.65   9.55   9.55    0.00      0.00
# 317434 2009-02-07   9.65   9.65   9.55   9.65    0.10      1.04
# 317435 2009-02-08   9.60   9.80   9.60   9.75    0.10      1.03
# 317437 2009-02-09   9.70   9.80   9.60   9.80    0.05      0.51
# 317438 2009-02-10   9.80   9.85   9.60   9.60   -0.20     -2.04
# 317439 2009-02-11   9.55   9.60   9.45   9.60    0.00      0.00
# ...           ...    ...    ...    ...    ...     ...       ...
# 315407 2019-10-20  19.80  20.12  19.62  20.12    0.58      2.97
# 315408 2019-10-21  20.10  20.26  19.84  20.26    0.14      0.70
# 315409 2019-10-22  20.28  20.70  20.00  20.58    0.32      1.58
# 315410 2019-10-23  20.78  20.78  20.44  20.76    0.18      0.87
# 315411 2019-10-24  20.52  20.78  20.52  20.76    0.00      0.00
# 315412 2019-10-27  20.90  20.96  20.76  20.84    0.08      0.39
# 315413 2019-10-28  20.80  20.80  20.62  20.80   -0.04     -0.19
# 315414 2019-10-29  20.60  20.74  19.96  20.70   -0.10     -0.48
# 315415 2019-10-30  20.50  20.70  20.34  20.70    0.00      0.00
# 315416 2019-10-31  20.32  20.78  20.32  20.78    0.08      0.39
# 315417 2019-11-03  20.50  20.52  20.40  20.40   -0.38     -1.83
# 315418 2019-11-04  20.30  20.72  20.28  20.72    0.32      1.57
# 315419 2019-11-05  20.48  20.94  20.46  20.94    0.22      1.06
# 315420 2019-11-06  20.90  20.94  20.80  20.90   -0.04     -0.19
# 315421 2019-11-07  20.90  20.90  20.82  20.90    0.00      0.00
# 315422 2019-11-10  20.90  20.90  20.50  20.70   -0.20     -0.96
# 315423 2019-11-11  20.56  20.62  20.54  20.60   -0.10     -0.48
# 315424 2019-11-12  20.56  20.80  20.54  20.78    0.18      0.87
# 315425 2019-11-13  20.76  20.84  20.60  20.84    0.06      0.29
# 315426 2019-11-14  20.68  20.90  20.68  20.90    0.06      0.29
# 315427 2019-11-17  20.68  20.90  20.66  20.78   -0.12     -0.57
# 315428 2019-11-18  20.78  20.82  20.66  20.66   -0.12     -0.58
# 315429 2019-11-19  20.68  20.88  20.68  20.88    0.22      1.06
# 315430 2019-11-20  20.78  20.90  20.76  20.90    0.02      0.10
# 315431 2019-11-21  20.72  20.84  20.72  20.74   -0.16     -0.77
# 315432 2019-11-24  20.74  20.74  20.70  20.70   -0.04     -0.19
# 315433 2019-11-25  20.70  20.88  20.54  20.54   -0.16     -0.77
# 315434 2019-11-26  20.74  20.82  20.34  20.44   -0.10     -0.49
# 315435 2019-11-27  20.44  20.62  20.16  20.20   -0.24     -1.17
# 315436 2019-11-28  20.28  20.48  19.84  20.28    0.08      0.40
#
# [2722 rows x 7 columns]

# %%
Riyadhb_for_model.reset_index(inplace=True)

# %%
window_len = 5

#Create a data point (i.e. a date) which splits the training and testing set
split_date = list(Riyadhb_for_model["Date"][-(227):])[0]

# %%
split_date
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
training_set, test_set = Riyadhb_for_model[Riyadhb_for_model['Date'] < split_date], Riyadhb_for_model[Riyadhb_for_model['Date'] >= split_date]

# %%
training_set.shape
# Out:
# (2495, 8)

# %%
test_set.shape
# Out:
# (227, 8)

# %%
training_set.set_index('Date',inplace=True)

# %%
test_set.set_index('Date',inplace=True)

# %%
# training_target = training_set.pop('Close')

# %%
# testing_target = test_set.pop('Close')

# %%
training_set = training_set.drop(['index'], 1)
test_set = test_set.drop(['index'], 1)

# %%
training = training_set.values

# %%
testing = test_set.values

# %%
testing[0]
# Out:
# array([15.16, 15.18, 15.1 , 15.16,  0.02,  0.13])

# %%
test_set[0:1]
# Out:
#              Open   High   Low  Close  Change  % Change
# Date
# 2019-01-01  15.16  15.18  15.1  15.16    0.02      0.13

# %%
training_set.tail(10)
# Out:
#              Open   High    Low  Close  Change  % Change
# Date
# 2018-12-18  16.00  16.44  15.98  16.20    0.22      1.38
# 2018-12-19  16.08  16.10  15.92  16.00   -0.20     -1.23
# 2018-12-20  16.00  16.06  15.16  15.30   -0.70     -4.38
# 2018-12-23  15.18  15.18  14.94  15.04   -0.26     -1.70
# 2018-12-24  15.06  15.22  15.04  15.10    0.06      0.40
# 2018-12-25  15.00  15.14  14.78  15.10    0.00      0.00
# 2018-12-26  15.10  15.28  15.00  15.12    0.02      0.13
# 2018-12-27  15.18  15.30  15.00  15.08   -0.04     -0.26
# 2018-12-30  15.06  15.18  15.06  15.12    0.04      0.27
# 2018-12-31  15.14  15.16  15.06  15.14    0.02      0.13

# %%
LSTM_training_inputs = []
for i in range(len(training)-window_len):
    temp_set = training[i:(i+window_len)].copy()
    
    LSTM_training_inputs.append(temp_set)
LSTM_training_outputs = training_set['Close'][window_len:].values
# LSTM_training_outputs = scaler.transform(LSTM_training_outputs)
# LSTM_training_outputs = np.reshape(LSTM_training_outputs, (len(LSTM_training_outputs),1,1))


LSTM_training_inputs = np.array(LSTM_training_inputs)
# LSTM_training_inputs = scaler.fit_transform(LSTM_training_inputs)
# LSTM_training_inputs = np.reshape(LSTM_training_inputs,(len(LSTM_training_inputs),window_len,1))

#Create windows for testing
LSTM_test_inputs = []
for i in range(len(testing)-window_len):
    temp_set1 = testing[i:(i+window_len)].copy()
    
    
    LSTM_test_inputs.append(temp_set1)
LSTM_test_outputs = test_set['Close'][window_len:].values
# LSTM_test_outputs = scaler.transform(LSTM_test_outputs)
 
LSTM_test_inputs = np.array(LSTM_test_inputs)
# LSTM_test_inputs = scaler.transform(LSTM_test_inputs)
# LSTM_test_inputs = np.reshape(LSTM_test_inputs,(len(LSTM_test_inputs),window_len,1))

# %%
LSTM_test_inputs
# Out:
# array([[[ 1.516e+01,  1.518e+01,  1.510e+01,  1.516e+01,  2.000e-02,
#           1.300e-01],
#         [ 1.514e+01,  1.516e+01,  1.510e+01,  1.516e+01,  0.000e+00,
#           0.000e+00],
#         [ 1.514e+01,  1.526e+01,  1.512e+01,  1.524e+01,  8.000e-02,
#           5.300e-01],
#         [ 1.526e+01,  1.526e+01,  1.512e+01,  1.518e+01, -6.000e-02,
#          -3.900e-01],
#         [ 1.522e+01,  1.522e+01,  1.498e+01,  1.504e+01, -1.400e-01,
#          -9.200e-01]],
#
#        [[ 1.514e+01,  1.516e+01,  1.510e+01,  1.516e+01,  0.000e+00,
#           0.000e+00],
#         [ 1.514e+01,  1.526e+01,  1.512e+01,  1.524e+01,  8.000e-02,
#           5.300e-01],
#         [ 1.526e+01,  1.526e+01,  1.512e+01,  1.518e+01, -6.000e-02,
#          -3.900e-01],
#         [ 1.522e+01,  1.522e+01,  1.498e+01,  1.504e+01, -1.400e-01,
#          -9.200e-01],
#         [ 1.504e+01,  1.512e+01,  1.500e+01,  1.510e+01,  6.000e-02,
#           4.000e-01]],
#
#        [[ 1.514e+01,  1.526e+01,  1.512e+01,  1.524e+01,  8.000e-02,
#           5.300e-01],
#         [ 1.526e+01,  1.526e+01,  1.512e+01,  1.518e+01, -6.000e-02,
#          -3.900e-01],
#         [ 1.522e+01,  1.522e+01,  1.498e+01,  1.504e+01, -1.400e-01,
#          -9.200e-01],
#         [ 1.504e+01,  1.512e+01,  1.500e+01,  1.510e+01,  6.000e-02,
#           4.000e-01],
#         [ 1.516e+01,  1.518e+01,  1.510e+01,  1.512e+01,  2.000e-02,
#           1.300e-01]],
#
#        ...,
#
#        [[ 2.068e+01,  2.088e+01,  2.068e+01,  2.088e+01,  2.200e-01,
#           1.060e+00],
#         [ 2.078e+01,  2.090e+01,  2.076e+01,  2.090e+01,  2.000e-02,
#           1.000e-01],
#         [ 2.072e+01,  2.084e+01,  2.072e+01,  2.074e+01, -1.600e-01,
#          -7.700e-01],
#         [ 2.074e+01,  2.074e+01,  2.070e+01,  2.070e+01, -4.000e-02,
#          -1.900e-01],
#         [ 2.070e+01,  2.088e+01,  2.054e+01,  2.054e+01, -1.600e-01,
#          -7.700e-01]],
#
#        [[ 2.078e+01,  2.090e+01,  2.076e+01,  2.090e+01,  2.000e-02,
#           1.000e-01],
#         [ 2.072e+01,  2.084e+01,  2.072e+01,  2.074e+01, -1.600e-01,
#          -7.700e-01],
#         [ 2.074e+01,  2.074e+01,  2.070e+01,  2.070e+01, -4.000e-02,
#          -1.900e-01],
#         [ 2.070e+01,  2.088e+01,  2.054e+01,  2.054e+01, -1.600e-01,
#          -7.700e-01],
#         [ 2.074e+01,  2.082e+01,  2.034e+01,  2.044e+01, -1.000e-01,
#          -4.900e-01]],
#
#        [[ 2.072e+01,  2.084e+01,  2.072e+01,  2.074e+01, -1.600e-01,
#          -7.700e-01],
#         [ 2.074e+01,  2.074e+01,  2.070e+01,  2.070e+01, -4.000e-02,
#          -1.900e-01],
#         [ 2.070e+01,  2.088e+01,  2.054e+01,  2.054e+01, -1.600e-01,
#          -7.700e-01],
#         [ 2.074e+01,  2.082e+01,  2.034e+01,  2.044e+01, -1.000e-01,
#          -4.900e-01],
#         [ 2.044e+01,  2.062e+01,  2.016e+01,  2.020e+01, -2.400e-01,
#          -1.170e+00]]])

# %%
LSTM_training_inputs
# Out:
# array([[[ 9.3 ,  9.45,  9.25,  9.35,  0.1 ,  1.08],
#         [ 9.35,  9.4 ,  9.3 ,  9.4 ,  0.05,  0.53],
#         [ 9.4 ,  9.55,  9.4 ,  9.45,  0.05,  0.53],
#         [ 9.5 ,  9.6 ,  9.45,  9.55,  0.1 ,  1.05],
#         [ 9.55,  9.85,  9.55,  9.8 ,  0.25,  2.61]],
#
#        [[ 9.35,  9.4 ,  9.3 ,  9.4 ,  0.05,  0.53],
#         [ 9.4 ,  9.55,  9.4 ,  9.45,  0.05,  0.53],
#         [ 9.5 ,  9.6 ,  9.45,  9.55,  0.1 ,  1.05],
#         [ 9.55,  9.85,  9.55,  9.8 ,  0.25,  2.61],
#         [ 9.6 ,  9.6 ,  9.45,  9.5 , -0.3 , -3.06]],
#
#        [[ 9.4 ,  9.55,  9.4 ,  9.45,  0.05,  0.53],
#         [ 9.5 ,  9.6 ,  9.45,  9.55,  0.1 ,  1.05],
#         [ 9.55,  9.85,  9.55,  9.8 ,  0.25,  2.61],
#         [ 9.6 ,  9.6 ,  9.45,  9.5 , -0.3 , -3.06],
#         [ 9.55,  9.7 ,  9.55,  9.55,  0.05,  0.52]],
#
#        ...,
#
#        [[16.  , 16.06, 15.16, 15.3 , -0.7 , -4.38],
#         [15.18, 15.18, 14.94, 15.04, -0.26, -1.7 ],
#         [15.06, 15.22, 15.04, 15.1 ,  0.06,  0.4 ],
#         [15.  , 15.14, 14.78, 15.1 ,  0.  ,  0.  ],
#         [15.1 , 15.28, 15.  , 15.12,  0.02,  0.13]],
#
#        [[15.18, 15.18, 14.94, 15.04, -0.26, -1.7 ],
#         [15.06, 15.22, 15.04, 15.1 ,  0.06,  0.4 ],
#         [15.  , 15.14, 14.78, 15.1 ,  0.  ,  0.  ],
#         [15.1 , 15.28, 15.  , 15.12,  0.02,  0.13],
#         [15.18, 15.3 , 15.  , 15.08, -0.04, -0.26]],
#
#        [[15.06, 15.22, 15.04, 15.1 ,  0.06,  0.4 ],
#         [15.  , 15.14, 14.78, 15.1 ,  0.  ,  0.  ],
#         [15.1 , 15.28, 15.  , 15.12,  0.02,  0.13],
#         [15.18, 15.3 , 15.  , 15.08, -0.04, -0.26],
#         [15.06, 15.18, 15.06, 15.12,  0.04,  0.27]]])

# %%
nn_model.reset_states()
nn_model.reset_metrics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c2217cfdbcf3> in <module>
# ----> 1 nn_model.reset_states()
#       2 nn_model.reset_metrics()
#
# NameError: name 'nn_model' is not defined

# %%
def build_model(inputs, output_size, neurons, activ_func="relu",
                dropout=0.10, loss="mae", optimizer="adam"):
    
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
nn_model = build_model(LSTM_training_inputs, output_size=1, neurons = 400)

nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                            epochs=120, batch_size=160, verbose=1,validation_split= 0.2)
# Out:
# Train on 1992 samples, validate on 498 samples
# Epoch 1/120
# 1992/1992 [==============================] - 1s 491us/step - loss: 7.1845 - val_loss: 5.6981
# Epoch 2/120
# 1992/1992 [==============================] - 0s 247us/step - loss: 2.3913 - val_loss: 7.6368
# Epoch 3/120
# 1992/1992 [==============================] - 1s 252us/step - loss: 2.0267 - val_loss: 6.8694
# Epoch 4/120
# 1992/1992 [==============================] - 1s 263us/step - loss: 1.9175 - val_loss: 6.8179
# Epoch 5/120
# 1992/1992 [==============================] - 1s 261us/step - loss: 1.7360 - val_loss: 6.1306
# 1992/1992 [==============================] - 1s 267us/step - loss: 0.2679 - val_loss: 0.5546
# Epoch 94/120
# 1992/1992 [==============================] - 1s 278us/step - loss: 0.2712 - val_loss: 0.6178
# Epoch 95/120
# 1992/1992 [==============================] - 1s 272us/step - loss: 0.2890 - val_loss: 0.5329
# Epoch 96/120
# 1992/1992 [==============================] - 1s 270us/step - loss: 0.2650 - val_loss: 0.5363
# Epoch 97/120
# 1992/1992 [==============================] - 1s 272us/step - loss: 0.2784 - val_loss: 0.5734
# Epoch 98/120
# 1992/1992 [==============================] - 1s 270us/step - loss: 0.2714 - val_loss: 0.5480
# Epoch 99/120
# 1992/1992 [==============================] - 1s 280us/step - loss: 0.2618 - val_loss: 0.6242
# Epoch 100/120
# 1992/1992 [==============================] - 1s 282us/step - loss: 0.2847 - val_loss: 0.4863
# Epoch 101/120
# 1992/1992 [==============================] - 1s 283us/step - loss: 0.2808 - val_loss: 0.4755
# Epoch 102/120
# 1992/1992 [==============================] - 1s 279us/step - loss: 0.2689 - val_loss: 0.6928
# Epoch 103/120
# 1992/1992 [==============================] - 1s 281us/step - loss: 0.2722 - val_loss: 0.5877
# Epoch 104/120
# 1992/1992 [==============================] - 1s 274us/step - loss: 0.2940 - val_loss: 0.4973
# Epoch 105/120
# 1992/1992 [==============================] - 1s 274us/step - loss: 0.2881 - val_loss: 0.5713
# Epoch 106/120
# 1992/1992 [==============================] - 1s 278us/step - loss: 0.2754 - val_loss: 0.5644
# Epoch 107/120
# 1992/1992 [==============================] - 1s 274us/step - loss: 0.2937 - val_loss: 0.5526
# Epoch 108/120
# 1992/1992 [==============================] - 1s 276us/step - loss: 0.2891 - val_loss: 0.6513
# Epoch 109/120
# 1992/1992 [==============================] - 1s 274us/step - loss: 0.2851 - val_loss: 0.6949
# Epoch 110/120
# 1992/1992 [==============================] - 1s 270us/step - loss: 0.2725 - val_loss: 0.5127
# Epoch 111/120
# 1992/1992 [==============================] - 1s 271us/step - loss: 0.2585 - val_loss: 0.4846
# Epoch 112/120
# 1992/1992 [==============================] - 1s 276us/step - loss: 0.2566 - val_loss: 0.6172
# Epoch 113/120
# 1992/1992 [==============================] - 1s 273us/step - loss: 0.2572 - val_loss: 0.5004
# Epoch 114/120
# 1992/1992 [==============================] - 1s 274us/step - loss: 0.2701 - val_loss: 0.5241
# Epoch 115/120
# 1992/1992 [==============================] - 1s 279us/step - loss: 0.2728 - val_loss: 0.4719
# Epoch 116/120
# 1992/1992 [==============================] - 1s 274us/step - loss: 0.2630 - val_loss: 0.5520
# Epoch 117/120
# 1992/1992 [==============================] - 1s 284us/step - loss: 0.2655 - val_loss: 0.4518
# Epoch 118/120
# 1992/1992 [==============================] - 1s 280us/step - loss: 0.2677 - val_loss: 0.4476
# Epoch 119/120
# 1992/1992 [==============================] - 1s 281us/step - loss: 0.2598 - val_loss: 0.7019
# Epoch 120/120
# 1992/1992 [==============================] - 1s 277us/step - loss: 0.2702 - val_loss: 0.5058

# %%
train_loss = nn_history.history['loss']
test_loss = nn_history.history['val_loss']
plt.plot(train_loss, label='Training loss')
plt.plot(test_loss, label='Testing loss')
plt.legend()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
fig = plt.subplots( figsize=(16,8))
plt.plot(LSTM_test_outputs, label = "actual")
plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
MSE = mean_squared_error(LSTM_test_outputs,nn_model.predict(LSTM_test_inputs))
R2_score = r2_score(LSTM_test_outputs,nn_model.predict(LSTM_test_inputs))
# RMSE = mean_squared_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
print('The Mean Absolute Error is: {}'.format(MAE))
print('The Mean squared Error is: {}'.format(MSE))
print('The R2 is: {}'.format(R2_score))
# print('The Mean Root mean squared error) Error is: {}'.format(RMSE))
# Out:
# The Mean Absolute Error is: 0.2353298467343992
# The Mean squared Error is: 0.1049919223443965
# The R2 is: 0.9738487354224968

# %%
fig = plt.subplots( figsize=(18,9))
plt.plot(LSTM_training_outputs, label = "actual")
plt.plot(nn_model.predict(LSTM_training_inputs), label = "predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_training_outputs, nn_model.predict(LSTM_training_inputs))
MSE = mean_squared_error(LSTM_training_outputs,nn_model.predict(LSTM_training_inputs))
R2_score = r2_score(LSTM_training_outputs,nn_model.predict(LSTM_training_inputs))

print('The Mean Absolute Error is: {}'.format(MAE))
print('The Mean squared Error is: {}'.format(MSE))
print('The R2 is: {}'.format(R2_score))
# Out:
# The Mean Absolute Error is: 0.21393047986930633
# The Mean squared Error is: 0.12937920072205206
# The R2 is: 0.9912375428318992

# %%
nn_model.get_config()
# Out:
# {'name': 'sequential_1',
#  'layers': [{'class_name': 'LSTM',
#    'config': {'name': 'lstm_1',
#     'trainable': True,
#     'batch_input_shape': (None, 5, 6),
#     'dtype': 'float32',
#     'return_sequences': False,
#     'return_state': False,
#     'go_backwards': False,
#     'stateful': False,
#     'unroll': False,
#     'units': 400,
#     'activation': 'tanh',
#     'recurrent_activation': 'sigmoid',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'recurrent_initializer': {'class_name': 'Orthogonal',
#      'config': {'gain': 1.0, 'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'unit_forget_bias': True,
#     'kernel_regularizer': None,
#     'recurrent_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'recurrent_constraint': None,
#     'bias_constraint': None,
#     'dropout': 0.0,
#     'recurrent_dropout': 0.0,
#     'implementation': 2}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.1,
#     'noise_shape': None,
#     'seed': None}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Activation',
#    'config': {'name': 'activation_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'}}]}

# %%
print(nn_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 400)               651200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 401
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 651,601
# Trainable params: 651,601
# Non-trainable params: 0
# _________________________________________________________________
# None
