# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences

from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.layers import Bidirectional
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler


from sklearn import linear_model 
from sklearn.metrics import mean_absolute_error
sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('Equites_Historical_NonAdjusted_Prices.csv', usecols=['Industry Group', 'Symbol', 'Company Name', 'Date', 'Open', 'High',
       'Low', 'Close', 'Change', '% Change', 'Volume Traded','Value Traded (SAR)', 'No. of Trades'])

# %%
df.Date = pd.to_datetime(df.Date, dayfirst=True)

# %%
df.sort_values('Date',inplace=True)

# %%
df['Company Name'].unique()[65]
# Out:
# 'Saudi Advanced Industries Co.'

# %%
df['Company Name'].groupby(df['Industry Group']).value_counts()
# Out:
# Industry Group                  Company Name
# Banks                           Al Rajhi Bank                                          2722
#                                 Alinma Bank                                            2722
#                                 Arab National Bank                                     2722
#                                 Bank Albilad                                           2722
#                                 Bank Aljazira                                          2722
#                                 Banque Saudi Fransi                                    2722
#                                 Riyad Bank                                             2722
#                                 Samba Financial Group                                  2722
#                                 Saudi British Bank                                     2722
#                                 Saudi Investment Bank                                  2722
#                                 National Commercial Bank                               1262
# Capital Goods                   Al-Ahsa Development Co.                                2722
#                                 Al-Babtain Power and Telecommunication Co.             2722
#                                 Astra Industrial Group                                 2722
#                                 Middle East Specialized Cables Co.                     2722
#                                 Saudi Arabian Amiantit Co.                             2722
#                                 Saudi Cable Co.                                        2722
#                                 Saudi Ceramic Co.                                      2722
#                                 Saudi Industrial Export Co.                            2722
#                                 Saudi Vitrified Clay Pipes Co.                         2722
#                                 Abdullah A. M. Al-Khodari Sons Co.                     2268
#                                 Mohammad Al Mojil Group                                2087
#                                 Bawan Co.                                              1482
#                                 Electrical Industries Co.                              1245
# Commercial & Professional Svc   Saudi Printing and Packaging Co.                       2722
#                                 Saudi Airlines Catering Co.                            1839
#                                 Maharah Human Resources Co.                             112
# Consumer Durables & Apparel     Al Abdullatif Industrial Investment Co.                2722
#                                 Fitaihi Holding Group                                  2722
#                                 Saudi Industrial Development Co.                       2722
#                                                                                        ...
# Real Estate Mgmt & Dev't        Emaar The Economic City                                2722
#                                 Jabal Omar Development Co.                             2722
#                                 Makkah Construction and Development Co.                2722
#                                 Red Sea International Co.                              2722
#                                 Saudi Real Estate Co.                                  2722
#                                 Taiba Investments Co.                                  2722
#                                 Knowledge Economic City                                2315
#                                 Alandalus Property Co.                                  968
#                                 Arabian Centres Co.                                     126
# Retailing                       Fawaz Abdulaziz Alhokair Co.                           2722
#                                 Jarir Marketing Co.                                    2722
#                                 Saudi Automotive Services Co.                          2722
#                                 Al Hassan Ghazi Ibrahim Shaker Co.                     2375
#                                 United Electronics Co.                                 1981
#                                 Saudi Company for Hardware                             1134
#                                 Abdullah Saad Mohammed Abo Moati for Bookstores Co.     686
# Software & Services             Al Moammar Information Systems Co.                      146
# Tadawul All Share Index (TASI)  Alawwal Bank                                           2610
# Telecommunication Services      Etihad Etisalat Co.                                    2722
#                                 Mobile Telecommunication Company Saudi Arabia          2722
#                                 Saudi Telecom Co.                                      2722
#                                 Etihad Atheeb Telecommunication Co.                    2667
#                                 Saudi Integrated Telecom Company                        399
# Transportation                  Batic Investments and Logistics Co.                    2722
#                                 Saudi Industrial Services Co.                          2722
#                                 Saudi Public Transport Co.                             2722
#                                 United International Transportation Co.                2722
#                                 Saudi Ground Services Co.                              1102
# Utilities                       National Gas and Industrialization Co.                 2722
#                                 Saudi Electricity Co.                                  2722
# Name: Company Name, Length: 205, dtype: int64

# %%
df[df['Industry Group'] == 'Banks']
# Out:
#       Industry Group  Symbol              Company Name       Date   Open  \
# 21064          Banks    1090     Samba Financial Group 2009-01-03  50.75
# 26503          Banks    1140              Bank Albilad 2009-01-03  28.10
# 6059           Banks    1030     Saudi Investment Bank 2009-01-03  16.95
# 2121           Banks    1010                Riyad Bank 2009-01-03  21.00
# 15620          Banks    1060        Saudi British Bank 2009-01-03  53.75
# 12898          Banks    1050       Banque Saudi Fransi 2009-01-03  44.60
# 23781          Banks    1120             Al Rajhi Bank 2009-01-03  57.00
# 27725          Banks    1150               Alinma Bank 2009-01-03  11.20
# 4843           Banks    1020             Bank Aljazira 2009-01-03  15.10
# 18343          Banks    1080        Arab National Bank 2009-01-03  31.00
# 12909          Banks    1050       Banque Saudi Fransi 2009-01-04  46.90
# 15631          Banks    1060        Saudi British Bank 2009-01-04  59.00
# 23776          Banks    1120             Al Rajhi Bank 2009-01-04  58.50
# 18353          Banks    1080        Arab National Bank 2009-01-04  34.20
# 2123           Banks    1010                Riyad Bank 2009-01-04  21.70
# 26498          Banks    1140              Bank Albilad 2009-01-04  28.80
# 27719          Banks    1150               Alinma Bank 2009-01-04  11.50
# 21075          Banks    1090     Samba Financial Group 2009-01-04  50.50
# 4845           Banks    1020             Bank Aljazira 2009-01-04  15.95
# 6061           Banks    1030     Saudi Investment Bank 2009-01-04  17.40
# 2133           Banks    1010                Riyad Bank 2009-01-05  21.45
# 21059          Banks    1090     Samba Financial Group 2009-01-05  51.00
# 27721          Banks    1150               Alinma Bank 2009-01-05  11.35
# 26499          Banks    1140              Bank Albilad 2009-01-05  28.30
# 6071           Banks    1030     Saudi Investment Bank 2009-01-05  17.45
# 18339          Banks    1080        Arab National Bank 2009-01-05  33.80
# 4855           Banks    1020             Bank Aljazira 2009-01-05  15.90
# 15616          Banks    1060        Saudi British Bank 2009-01-05  59.00
# 12894          Banks    1050       Banque Saudi Fransi 2009-01-05  47.40
# 23777          Banks    1120             Al Rajhi Bank 2009-01-05  58.50
# ...              ...     ...                       ...        ...    ...
# 10805          Banks    1050       Banque Saudi Fransi 2019-11-26  33.90
# 29814          Banks    1150               Alinma Bank 2019-11-26  22.86
# 29860          Banks    1180  National Commercial Bank 2019-11-26  47.20
# 18967          Banks    1090     Samba Financial Group 2019-11-26  30.00
# 16249          Banks    1080        Arab National Bank 2019-11-26  25.50
# 21682          Banks    1120             Al Rajhi Bank 2019-11-26  64.50
# 13527          Banks    1060        Saudi British Bank 2019-11-26  36.40
# 2751           Banks    1020             Bank Aljazira 2019-11-26  13.80
# 2747           Banks    1020             Bank Aljazira 2019-11-27  13.74
# 29815          Banks    1150               Alinma Bank 2019-11-27  22.82
# 29861          Banks    1180  National Commercial Bank 2019-11-27  45.60
# 13523          Banks    1060        Saudi British Bank 2019-11-27  37.05
# 25             Banks    1010                Riyad Bank 2019-11-27  21.76
# 18968          Banks    1090     Samba Financial Group 2019-11-27  29.60
# 16245          Banks    1080        Arab National Bank 2019-11-27  25.40
# 21683          Banks    1120             Al Rajhi Bank 2019-11-27  63.00
# 10801          Banks    1050       Banque Saudi Fransi 2019-11-27  33.55
# 8156           Banks    1030     Saudi Investment Bank 2019-11-27  16.20
# 24405          Banks    1140              Bank Albilad 2019-11-27  25.80
# 26             Banks    1010                Riyad Bank 2019-11-28  21.70
# 29816          Banks    1150               Alinma Bank 2019-11-28  22.60
# 29862          Banks    1180  National Commercial Bank 2019-11-28  45.25
# 13524          Banks    1060        Saudi British Bank 2019-11-28  35.65
# 21684          Banks    1120             Al Rajhi Bank 2019-11-28  62.30
# 18969          Banks    1090     Samba Financial Group 2019-11-28  29.15
# 16246          Banks    1080        Arab National Bank 2019-11-28  25.10
# 2748           Banks    1020             Bank Aljazira 2019-11-28  13.70
# 8157           Banks    1030     Saudi Investment Bank 2019-11-28  16.12
# 10802          Banks    1050       Banque Saudi Fransi 2019-11-28  33.60
# 24406          Banks    1140              Bank Albilad 2019-11-28  25.55
#
#         High    Low  Close  Change  % Change  Volume Traded  \
# 21064  52.00  50.50  50.50   -0.75     -1.46         455859
# 26503  29.10  28.10  28.30    0.30      1.07         606031
# 6059   17.75  16.95  17.20    0.65      3.92         160643
# 2121   21.85  21.00  21.75    0.55      2.59         589847
# 15620  57.50  53.75  56.50    2.50      4.62          25475
# 12898  47.00  44.60  47.00    1.90      4.21         173113
# 23781  59.50  57.00  58.50    2.50      4.46        3118489
# 27725  11.65  11.20  11.55    0.45      4.05       88413603
# 4843   15.95  15.10  15.95    0.90      5.98        1600168
# 18343  34.30  31.00  34.20    3.00      9.61         333363
# 12909  47.70  46.30  47.60    0.60      1.27          54976
# 15631  59.00  56.75  59.00    2.50      4.42         109403
# 23776  59.25  58.00  58.50    0.00      0.00        2061488
# 18353  34.20  33.60  33.90   -0.30     -0.87         111997
# 2123   21.70  21.30  21.65   -0.10     -0.45         417290
# 26498  28.80  28.10  28.30    0.00      0.00         318159
# 27719  11.55  11.30  11.40   -0.15     -1.29       41653825
# 21075  51.50  49.20  51.00    0.50      0.99         499052
# 4845   16.00  15.75  16.00    0.05      0.31         620236
# 6061   17.65  17.10  17.50    0.30      1.74         123197
# 2133   21.80  21.45  21.80    0.15      0.69         708922
# 21059  52.75  50.00  52.00    1.00      1.96         590313
# 27721  11.75  11.30  11.65    0.25      2.19      115906810
# 26499  28.60  28.20  28.50    0.20      0.70         710615
# 6071   18.00  17.40  18.00    0.50      2.85         227891
# 18339  34.30  33.70  34.20    0.30      0.88         314626
# 4855   16.30  15.85  16.15    0.15      0.93         850707
# 15616  60.00  58.00  60.00    1.00      1.69          32137
# 12894  49.60  47.00  49.40    1.80      3.78         331910
# 23777  60.75  58.25  60.00    1.50      2.56        2546478
# ...      ...    ...    ...     ...       ...            ...
# 10805  34.15  33.25  33.25   -0.50     -1.48        1705692
# 29814  22.94  22.76  22.94    0.06      0.26        8692766
# 29860  47.20  45.25  45.25   -1.90     -4.03        3471303
# 18967  30.10  29.25  29.25   -0.90     -2.99        3733599
# 16249  25.50  24.56  25.40    0.05      0.20       38496434
# 21682  64.70  62.40  62.40   -2.10     -3.26       10942758
# 13527  37.05  35.30  37.05    1.05      2.92       24296158
# 2751   13.80  13.68  13.80    0.00      0.00        4077882
# 2747   13.76  13.66  13.70   -0.10     -0.72        1785640
# 29815  22.96  22.54  22.58   -0.36     -1.57        6355979
# 29861  45.70  45.00  45.45    0.20      0.44         997797
# 13523  37.05  35.35  35.80   -1.25     -3.37        2188102
# 25     21.90  21.70  21.72    0.14      0.65        1637540
# 18968  29.80  29.10  29.35    0.10      0.34         941829
# 16245  25.45  24.96  25.30   -0.10     -0.39        2808634
# 21683  63.60  61.70  61.80   -0.60     -0.96        6982091
# 10801  34.00  33.55  34.00    0.75      2.26         551020
# 8156   16.22  16.20  16.22    0.00      0.00          10703
# 24405  26.20  25.65  25.75    0.00      0.00         483048
# 26     22.18  21.66  22.00    0.28      1.29        1693876
# 29816  22.84  22.56  22.80    0.22      0.97        6644812
# 29862  46.35  45.25  46.00    0.55      1.21         918311
# 13524  35.80  34.10  34.10   -1.70     -4.75        1486330
# 21684  63.10  61.90  62.20    0.40      0.65        5262266
# 18969  29.25  28.55  29.15   -0.20     -0.68        1495836
# 16246  25.85  25.10  25.50    0.20      0.79        6260315
# 2748   13.72  13.62  13.62   -0.08     -0.58        1460270
# 8157   16.20  16.08  16.20   -0.02     -0.12         131084
# 10802  33.85  33.35  33.50   -0.50     -1.47         610294
# 24406  25.90  25.50  25.80    0.05      0.19         337363
#
#        Value Traded (SAR)  No. of Trades
# 21064        2.334883e+07            678
# 26503        1.736057e+07            612
# 6059         2.782922e+06            111
# 2121         1.274388e+07            517
# 15620        1.436504e+06             93
# 12898        8.040055e+06            185
# 23781        1.820464e+08           2865
# 27725        1.014294e+09           9448
# 4843         2.476491e+07            718
# 18343        1.124767e+07            370
# 12909        2.590814e+06            109
# 15631        6.360746e+06            100
# 23776        1.206332e+08           1728
# 18353        3.798586e+06            109
# 2123         8.990776e+06            409
# 26498        9.002257e+06            505
# 27719        4.756178e+08           6089
# 21075        2.532698e+07            631
# 4845         9.883137e+06            393
# 6061         2.152199e+06            129
# 2133         1.536708e+07            526
# 21059        3.040180e+07            552
# 27721        1.345981e+09           9801
# 26499        2.018271e+07            726
# 6071         4.033047e+06            118
# 18339        1.068190e+07            224
# 4855         1.370087e+07            545
# 15616        1.912713e+06             41
# 12894        1.613006e+07            199
# 23777        1.522310e+08           2285
# ...                   ...            ...
# 10805        5.686627e+07            586
# 29814        1.987630e+08           4066
# 29860        1.578093e+08           1196
# 18967        1.099714e+08           1108
# 16249        9.749139e+08           6005
# 21682        6.913918e+08           6510
# 13527        8.971989e+08           2936
# 2751         5.614679e+07            970
# 2747         2.448475e+07            784
# 29815        1.450239e+08           4536
# 29861        4.513672e+07           1401
# 13523        7.855653e+07           2070
# 25           3.568464e+07           1175
# 18968        2.773024e+07           1078
# 16245        7.080241e+07           1336
# 21683        4.395077e+08           6031
# 10801        1.868539e+07            459
# 8156         1.734346e+05             23
# 24405        1.248180e+07           1048
# 26           3.671371e+07            852
# 29816        1.507655e+08           4950
# 29862        4.217433e+07            989
# 13524        5.115902e+07           1369
# 21684        3.284859e+08           4586
# 18969        4.299681e+07           1233
# 16246        1.582016e+08            924
# 2748         1.999186e+07            815
# 8157         1.988629e+06             35
# 10802        2.010179e+07            522
# 24406        8.675895e+06            681
#
# [28482 rows x 13 columns]

# %%
Riyad_Bank = df[df['Company Name']== 'Saudi Telecom Co.']

# %%
Riyadhb_for_model = Riyad_Bank[['Date','Open', 'High', 'Low',
       'Close', 'Change', '% Change']]

# %%
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaled = scaler.fit_transform(Riyad_Bank[['Open', 'High', 'Low',
#        'Close', 'Change']])

# %%
# scaled_df = pd.DataFrame()

# %%
Riyadhb_for_model
# Out:
#              Date    Open    High     Low   Close  Change  % Change
# 347832 2009-01-03   49.80   52.00   49.80   51.50    2.40      4.88
# 347834 2009-01-04   51.75   52.50   51.25   52.00    0.50      0.97
# 347835 2009-01-05   52.00   53.25   51.50   52.75    0.75      1.44
# 347836 2009-01-06   52.00   53.00   52.00   52.50   -0.25     -0.47
# 347838 2009-01-07   52.25   55.00   52.25   54.00    1.50      2.85
# 347839 2009-01-10   53.50   53.50   52.00   53.00   -1.00     -1.85
# 347841 2009-01-11   52.75   53.50   51.75   51.75   -1.25     -2.35
# 347842 2009-01-12   52.00   52.50   51.50   52.00    0.25      0.48
# 347806 2009-01-13   52.00   52.75   50.75   52.25    0.25      0.48
# 347808 2009-01-14   51.75   54.25   51.50   53.00    0.75      1.43
# 347809 2009-01-17   52.00   52.25   49.10   51.75   -1.25     -2.35
# 347811 2009-01-18   51.50   52.75   51.00   51.00   -0.75     -1.44
# 347812 2009-01-19   51.25   52.00   50.00   50.25   -0.75     -1.47
# 347814 2009-01-20   49.50   51.50   48.00   51.00    0.75      1.49
# 347815 2009-01-21   45.90   47.20   45.90   45.90   -5.10    -10.00
# 347816 2009-01-24   46.40   48.30   46.40   47.60    1.70      3.70
# 347818 2009-01-25   48.00   48.00   45.20   47.50   -0.10     -0.21
# 347819 2009-01-26   47.60   47.80   46.90   47.50    0.00      0.00
# 347821 2009-01-27   47.50   48.10   47.10   47.20   -0.30     -0.63
# 347822 2009-01-28   47.00   47.40   47.00   47.10   -0.10     -0.21
# 347824 2009-01-31   47.00   47.40   46.80   47.10    0.00      0.00
# 347825 2009-02-01   47.20   47.20   46.20   46.50   -0.60     -1.27
# 347787 2009-02-02   46.00   46.60   45.80   45.90   -0.60     -1.29
# 347789 2009-02-03   45.80   45.90   45.50   45.90    0.00      0.00
# 347790 2009-02-04   45.90   46.00   45.30   45.30   -0.60     -1.30
# 347792 2009-02-07   45.50   45.80   44.80   45.00   -0.30     -0.66
# 347793 2009-02-08   45.30   45.50   44.90   45.00    0.00      0.00
# 347795 2009-02-09   45.00   45.20   44.80   45.10    0.10      0.22
# 347796 2009-02-10   45.00   45.20   44.50   44.50   -0.60     -1.33
# 347797 2009-02-11   44.00   44.00   43.20   43.20   -1.30     -2.92
# ...           ...     ...     ...     ...     ...     ...       ...
# 349855 2019-10-20  101.20  103.40  101.20  102.00    2.10      2.10
# 349856 2019-10-21  102.20  102.20  100.40  101.00   -1.00     -0.98
# 349857 2019-10-22  101.60  102.80  100.60  101.00    0.00      0.00
# 349858 2019-10-23  101.00  101.20   99.70  100.20   -0.80     -0.79
# 349859 2019-10-24  100.20  100.40   99.40   99.70   -0.50     -0.50
# 349860 2019-10-27   99.90  100.40   99.20   99.30   -0.40     -0.40
# 349861 2019-10-28   99.60   99.60   98.60   99.00   -0.30     -0.30
# 349862 2019-10-29   98.60   98.80   96.00   97.60   -1.40     -1.41
# 349838 2019-10-30   96.60   97.60   96.10   97.50   -0.10     -0.10
# 349839 2019-10-31   97.50   97.50   95.60   95.80   -1.70     -1.74
# 349840 2019-11-03   95.40   95.40   93.50   94.10   -1.70     -1.77
# 349841 2019-11-04   94.00   95.00   93.50   95.00    0.90      0.96
# 349842 2019-11-05   95.00   97.40   94.70   96.70    1.70      1.79
# 349843 2019-11-06   97.00   97.00   96.00   96.50   -0.20     -0.21
# 349844 2019-11-07   96.20   97.40   95.70   96.00   -0.50     -0.52
# 349845 2019-11-10   96.80   98.10   95.90   95.90   -0.10     -0.10
# 349846 2019-11-11   95.90   96.40   95.40   96.00    0.10      0.10
# 349847 2019-11-12   96.10   98.50   96.00   97.70    1.70      1.77
# 349848 2019-11-13   97.80   98.50   96.60   97.00   -0.70     -0.72
# 349849 2019-11-14   97.00  100.20   96.60   99.00    2.00      2.06
# 349828 2019-11-17   99.20   99.20   97.50   98.00   -1.00     -1.01
# 349829 2019-11-18   98.70   99.10   98.00   98.80    0.80      0.82
# 349830 2019-11-19   98.90  100.20   98.00   99.50    0.70      0.71
# 349831 2019-11-20  100.00  100.60   99.60  100.00    0.50      0.50
# 349832 2019-11-21  100.20  100.20   99.00   99.70   -0.30     -0.30
# 349833 2019-11-24   99.90   99.90   97.20   97.80   -1.90     -1.91
# 349834 2019-11-25   97.80   98.40   95.90   95.90   -1.90     -1.94
# 349835 2019-11-26   96.10   96.40   94.60   94.60   -1.30     -1.36
# 349836 2019-11-27   95.00   95.00   92.80   93.90   -0.70     -0.74
# 349837 2019-11-28   93.90   93.90   92.60   93.20   -0.70     -0.75
#
# [2722 rows x 7 columns]

# %%
Riyadhb_for_model.reset_index(inplace=True)

# %%
window_len = 1

#Create a data point (i.e. a date) which splits the training and testing set
split_date = list(Riyadhb_for_model["Date"][-(227):])[0]

# %%
split_date
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
training_set, test_set = Riyadhb_for_model[Riyadhb_for_model['Date'] < split_date], Riyadhb_for_model[Riyadhb_for_model['Date'] >= split_date]

# %%
training_set.shape
# Out:
# (2495, 8)

# %%
test_set.shape
# Out:
# (227, 8)

# %%
training_set.set_index('Date',inplace=True)

# %%
test_set.set_index('Date',inplace=True)

# %%
# training_target = training_set.pop('Close')

# %%
# testing_target = test_set.pop('Close')

# %%
training_set = training_set.drop(['index'], 1)
test_set = test_set.drop(['index'], 1)

# %%
training = training_set.values

# %%
testing = test_set.values

# %%
testing[0]
# Out:
# array([91.6 , 91.8 , 91.2 , 91.5 , -0.3 , -0.33])

# %%
test_set[0:1]
# Out:
#             Open  High   Low  Close  Change  % Change
# Date
# 2019-01-01  91.6  91.8  91.2   91.5    -0.3     -0.33

# %%
training_set.tail(10)
# Out:
#             Open  High   Low  Close  Change  % Change
# Date
# 2018-12-18  90.5  91.3  89.7   91.1     0.6      0.66
# 2018-12-19  91.0  91.3  90.8   91.1     0.0      0.00
# 2018-12-20  90.9  90.9  89.9   90.9    -0.2     -0.22
# 2018-12-23  90.9  91.1  89.2   90.5    -0.4     -0.44
# 2018-12-24  90.4  91.9  90.4   91.5     1.0      1.10
# 2018-12-25  91.0  91.5  90.5   91.1    -0.4     -0.44
# 2018-12-26  90.8  91.0  90.6   90.7    -0.4     -0.44
# 2018-12-27  90.9  91.5  90.8   91.5     0.8      0.88
# 2018-12-30  91.8  92.0  91.5   91.8     0.3      0.33
# 2018-12-31  91.8  92.0  91.4   91.8     0.0      0.00

# %%
LSTM_training_inputs = []
for i in range(len(training)-window_len):
    temp_set = training[i:(i+window_len)].copy()
    
    LSTM_training_inputs.append(temp_set)
LSTM_training_outputs = training_set['Close'][window_len:].values
# LSTM_training_outputs = scaler.transform(LSTM_training_outputs)
# LSTM_training_outputs = np.reshape(LSTM_training_outputs, (len(LSTM_training_outputs),1,1))


LSTM_training_inputs = np.array(LSTM_training_inputs)
# LSTM_training_inputs = scaler.fit_transform(LSTM_training_inputs)
# LSTM_training_inputs = np.reshape(LSTM_training_inputs,(len(LSTM_training_inputs),window_len,1))

#Create windows for testing
LSTM_test_inputs = []
for i in range(len(testing)-window_len):
    temp_set1 = testing[i:(i+window_len)].copy()
    
    
    LSTM_test_inputs.append(temp_set1)
LSTM_test_outputs = test_set['Close'][window_len:].values
# LSTM_test_outputs = scaler.transform(LSTM_test_outputs)
 
LSTM_test_inputs = np.array(LSTM_test_inputs)
# LSTM_test_inputs = scaler.transform(LSTM_test_inputs)
# LSTM_test_inputs = np.reshape(LSTM_test_inputs,(len(LSTM_test_inputs),window_len,1))

# %%
LSTM_test_inputs
# Out:
# array([[[91.6 , 91.8 , 91.2 , 91.5 , -0.3 , -0.33]],
#
#        [[91.9 , 93.4 , 91.5 , 93.  ,  1.5 ,  1.64]],
#
#        [[93.4 , 95.6 , 93.  , 95.  ,  2.  ,  2.15]],
#
#        ...,
#
#        [[97.8 , 98.4 , 95.9 , 95.9 , -1.9 , -1.94]],
#
#        [[96.1 , 96.4 , 94.6 , 94.6 , -1.3 , -1.36]],
#
#        [[95.  , 95.  , 92.8 , 93.9 , -0.7 , -0.74]]])

# %%
LSTM_training_inputs.shape
# Out:
# (2494, 1, 6)

# %%
nn_model.reset_states()
nn_model.reset_metrics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c2217cfdbcf3> in <module>
# ----> 1 nn_model.reset_states()
#       2 nn_model.reset_metrics()
#
# NameError: name 'nn_model' is not defined

# %%
def build_model(inputs, output_size, neurons, activ_func="relu",
                dropout=0.10, loss="mae", optimizer="adam"):
    
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
nn_model = build_model(LSTM_training_inputs, output_size=1, neurons = 400)

nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                            epochs=120, batch_size=200, verbose=1,validation_split= 0.2)
# Out:
# Train on 1995 samples, validate on 499 samples
# Epoch 1/120
# 1995/1995 [==============================] - 1s 607us/step - loss: 46.9301 - val_loss: 69.2067
# Epoch 2/120
# 1995/1995 [==============================] - 0s 97us/step - loss: 41.5571 - val_loss: 63.6967
# Epoch 3/120
# 1995/1995 [==============================] - 0s 95us/step - loss: 36.6257 - val_loss: 59.2649
# Epoch 4/120
# 1995/1995 [==============================] - 0s 98us/step - loss: 32.4500 - val_loss: 55.5247
# Epoch 5/120
# 1995/1995 [==============================] - 0s 100us/step - loss: 28.6845 - val_loss: 51.8869
# Epoch 6/120
# 1995/1995 [==============================] - 0s 102us/step - loss: 25.0064 - val_loss: 48.1713
# Epoch 7/120
# 1995/1995 [==============================] - 0s 103us/step - loss: 21.3648 - val_loss: 44.8286
# Epoch 8/120
# 1995/1995 [==============================] - 0s 105us/step - loss: 17.7396 - val_loss: 40.7714
# Epoch 9/120
# 1995/1995 [==============================] - 0s 100us/step - loss: 14.2154 - val_loss: 37.1364
# Epoch 10/120
# 1995/1995 [==============================] - 0s 104us/step - loss: 12.0942 - val_loss: 34.4302
# Epoch 11/120
# 1995/1995 [==============================] - 0s 100us/step - loss: 11.3457 - val_loss: 32.7402
# Epoch 12/120
# 1995/1995 [==============================] - 0s 105us/step - loss: 11.1141 - val_loss: 31.7192
# Epoch 13/120
# 1995/1995 [==============================] - 0s 112us/step - loss: 10.9718 - val_loss: 31.1496
# Epoch 14/120
# 1995/1995 [==============================] - 0s 106us/step - loss: 10.8006 - val_loss: 30.6425
# Epoch 15/120
# 1995/1995 [==============================] - 0s 107us/step - loss: 10.6883 - val_loss: 30.3253
# Epoch 16/120
# 1995/1995 [==============================] - 0s 107us/step - loss: 10.5683 - val_loss: 30.4682
# Epoch 17/120
# 1995/1995 [==============================] - 0s 107us/step - loss: 10.3599 - val_loss: 29.9571
# Epoch 18/120
# 1995/1995 [==============================] - 0s 112us/step - loss: 9.9920 - val_loss: 29.3730
# Epoch 19/120
# 1995/1995 [==============================] - 0s 106us/step - loss: 9.4590 - val_loss: 28.7778
# Epoch 20/120
# 1995/1995 [==============================] - 0s 102us/step - loss: 8.8539 - val_loss: 27.8132
# Epoch 21/120
# 1995/1995 [==============================] - 0s 100us/step - loss: 8.3002 - val_loss: 26.8284
# Epoch 22/120
# 1995/1995 [==============================] - 0s 100us/step - loss: 7.7646 - val_loss: 25.2841
# Epoch 23/120
# 1995/1995 [==============================] - 0s 107us/step - loss: 7.2686 - val_loss: 24.2132
# Epoch 24/120
# 1995/1995 [==============================] - 0s 107us/step - loss: 6.7570 - val_loss: 23.4021
# Epoch 25/120
# 1995/1995 [==============================] - 0s 106us/step - loss: 6.3255 - val_loss: 22.2703
# Epoch 26/120
# 1995/1995 [==============================] - 0s 101us/step - loss: 5.8994 - val_loss: 20.9247
# Epoch 27/120
# 1995/1995 [==============================] - 0s 126us/step - loss: 5.4850 - val_loss: 20.3136
# Epoch 28/120
# 1995/1995 [==============================] - 0s 115us/step - loss: 5.1153 - val_loss: 19.1936
# Epoch 29/120
# 1995/1995 [==============================] - 0s 108us/step - loss: 4.7016 - val_loss: 17.6070
# Epoch 30/120
# 1995/1995 [==============================] - 0s 113us/step - loss: 4.3620 - val_loss: 16.4446
# Epoch 31/120
# 1995/1995 [==============================] - 0s 119us/step - loss: 4.0798 - val_loss: 16.0759
# Epoch 32/120
# 1995/1995 [==============================] - 0s 122us/step - loss: 3.8208 - val_loss: 15.8143
# Epoch 33/120
# 1995/1995 [==============================] - 0s 110us/step - loss: 3.6196 - val_loss: 14.7932
# Epoch 34/120
# 1995/1995 [==============================] - 0s 102us/step - loss: 3.2592 - val_loss: 13.3279
# Epoch 35/120
# 1995/1995 [==============================] - 0s 110us/step - loss: 2.9410 - val_loss: 12.2025
# Epoch 36/120
# 1995/1995 [==============================] - 0s 112us/step - loss: 2.7875 - val_loss: 12.2087
# Epoch 37/120
# 1995/1995 [==============================] - 0s 89us/step - loss: 2.5132 - val_loss: 10.8724
# Epoch 38/120
# 1995/1995 [==============================] - 0s 87us/step - loss: 2.3925 - val_loss: 10.8266
# Epoch 39/120
# 1995/1995 [==============================] - 0s 93us/step - loss: 2.1874 - val_loss: 9.8958
# Epoch 40/120
# 1995/1995 [==============================] - 0s 116us/step - loss: 2.3821 - val_loss: 10.7635
# Epoch 41/120
# 1995/1995 [==============================] - 0s 110us/step - loss: 2.3528 - val_loss: 9.4266
# Epoch 42/120
# 1995/1995 [==============================] - 0s 118us/step - loss: 2.1088 - val_loss: 8.3140
# Epoch 43/120
# 1995/1995 [==============================] - 0s 90us/step - loss: 1.9038 - val_loss: 8.1949
# Epoch 44/120
# 1995/1995 [==============================] - 0s 91us/step - loss: 1.7206 - val_loss: 8.0004
# Epoch 45/120
# 1995/1995 [==============================] - 0s 80us/step - loss: 1.7207 - val_loss: 7.5459
# Epoch 46/120
# 1995/1995 [==============================] - 0s 102us/step - loss: 1.6899 - val_loss: 6.5582
# Epoch 47/120
# 1995/1995 [==============================] - 0s 97us/step - loss: 1.6950 - val_loss: 7.6459
# Epoch 48/120
# 1995/1995 [==============================] - 0s 98us/step - loss: 1.6323 - val_loss: 6.4953
# Epoch 49/120
# 1995/1995 [==============================] - 0s 93us/step - loss: 1.6096 - val_loss: 6.6450
# Epoch 50/120
# 1995/1995 [==============================] - 0s 91us/step - loss: 1.6409 - val_loss: 7.3062
# Epoch 51/120
# 1995/1995 [==============================] - 0s 113us/step - loss: 1.7417 - val_loss: 7.0197
# Epoch 52/120
# 1995/1995 [==============================] - 0s 116us/step - loss: 1.6763 - val_loss: 6.4895
# Epoch 53/120
# 1995/1995 [==============================] - 0s 88us/step - loss: 1.4763 - val_loss: 6.1464
# Epoch 54/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 1.4546 - val_loss: 6.1973
# Epoch 55/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 1.4947 - val_loss: 5.2677
# Epoch 56/120
# 1995/1995 [==============================] - 0s 86us/step - loss: 1.6139 - val_loss: 6.3193
# Epoch 57/120
# 1995/1995 [==============================] - 0s 92us/step - loss: 1.5181 - val_loss: 6.3125
# Epoch 58/120
# 1995/1995 [==============================] - 0s 90us/step - loss: 1.4033 - val_loss: 5.3615
# Epoch 59/120
# 1995/1995 [==============================] - 0s 89us/step - loss: 1.4606 - val_loss: 6.1438
# Epoch 60/120
# 1995/1995 [==============================] - 0s 83us/step - loss: 1.4877 - val_loss: 6.4737
# Epoch 61/120
# 1995/1995 [==============================] - 0s 82us/step - loss: 1.5322 - val_loss: 5.3858
# Epoch 62/120
# 1995/1995 [==============================] - 0s 90us/step - loss: 1.3562 - val_loss: 5.3984
# Epoch 63/120
# 1995/1995 [==============================] - 0s 94us/step - loss: 1.3505 - val_loss: 5.5309
# Epoch 64/120
# 1995/1995 [==============================] - 0s 88us/step - loss: 1.3510 - val_loss: 5.7546
# Epoch 65/120
# 1995/1995 [==============================] - 0s 98us/step - loss: 1.3898 - val_loss: 5.9466
# Epoch 66/120
# 1995/1995 [==============================] - 0s 99us/step - loss: 1.3367 - val_loss: 4.8884
# Epoch 67/120
# 1995/1995 [==============================] - 0s 81us/step - loss: 1.3905 - val_loss: 5.8760
# Epoch 68/120
# 1995/1995 [==============================] - 0s 81us/step - loss: 1.4275 - val_loss: 5.2331
# Epoch 69/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 1.3661 - val_loss: 4.9946
# Epoch 70/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.3533 - val_loss: 5.1870
# Epoch 71/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 1.3909 - val_loss: 4.6317
# Epoch 72/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 1.3309 - val_loss: 5.1827
# Epoch 73/120
# 1995/1995 [==============================] - 0s 82us/step - loss: 1.2818 - val_loss: 4.7121
# Epoch 74/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.3121 - val_loss: 4.7383
# Epoch 75/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 1.2733 - val_loss: 4.9492
# Epoch 76/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 1.3053 - val_loss: 4.8577
# Epoch 77/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 1.2652 - val_loss: 4.7515
# Epoch 78/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 1.2458 - val_loss: 4.3721
# Epoch 79/120
# 1995/1995 [==============================] - 0s 86us/step - loss: 1.2974 - val_loss: 4.8515
# Epoch 80/120
# 1995/1995 [==============================] - 0s 85us/step - loss: 1.8466 - val_loss: 3.5864
# Epoch 81/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 1.9645 - val_loss: 3.7305
# Epoch 82/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 1.8721 - val_loss: 3.8409
# Epoch 83/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 1.4606 - val_loss: 3.8395
# Epoch 84/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 1.2887 - val_loss: 4.4397
# Epoch 85/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 1.2084 - val_loss: 4.9999
# Epoch 86/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.2062 - val_loss: 4.2120
# Epoch 87/120
# 1995/1995 [==============================] - 0s 80us/step - loss: 1.2385 - val_loss: 4.6801
# Epoch 88/120
# 1995/1995 [==============================] - 0s 87us/step - loss: 1.1768 - val_loss: 4.4600
# Epoch 89/120
# 1995/1995 [==============================] - 0s 86us/step - loss: 1.1654 - val_loss: 4.4304
# Epoch 90/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 1.1752 - val_loss: 4.4147
# Epoch 91/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 1.2516 - val_loss: 4.5753
# Epoch 92/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 1.2058 - val_loss: 4.2308
# Epoch 93/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 1.1681 - val_loss: 4.7646
# Epoch 94/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 1.2202 - val_loss: 3.4644
# Epoch 95/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 1.3082 - val_loss: 4.7686
# Epoch 96/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 1.1891 - val_loss: 4.0540
# Epoch 97/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 1.2733 - val_loss: 5.1720
# Epoch 98/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 1.2556 - val_loss: 3.7404
# Epoch 99/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.1508 - val_loss: 4.2653
# Epoch 100/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 1.2953 - val_loss: 3.7567
# Epoch 101/120
# 1995/1995 [==============================] - 0s 89us/step - loss: 1.3742 - val_loss: 4.7298
# Epoch 102/120
# 1995/1995 [==============================] - 0s 85us/step - loss: 1.1943 - val_loss: 3.9109
# Epoch 103/120
# 1995/1995 [==============================] - 0s 82us/step - loss: 1.1403 - val_loss: 3.7117
# Epoch 104/120
# 1995/1995 [==============================] - 0s 83us/step - loss: 1.1631 - val_loss: 4.6766
# Epoch 105/120
# 1995/1995 [==============================] - 0s 84us/step - loss: 1.1416 - val_loss: 3.8394
# Epoch 106/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.1493 - val_loss: 3.7367
# Epoch 107/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.1167 - val_loss: 4.3557
# Epoch 108/120
# 1995/1995 [==============================] - 0s 69us/step - loss: 1.1425 - val_loss: 3.7013
# Epoch 109/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.1226 - val_loss: 3.8288
# Epoch 110/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 1.1402 - val_loss: 3.3436
# Epoch 111/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.1865 - val_loss: 3.2077
# Epoch 112/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.2288 - val_loss: 4.6288
# Epoch 113/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 1.1834 - val_loss: 4.4178
# Epoch 114/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 1.3222 - val_loss: 3.0592
# Epoch 115/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 1.1787 - val_loss: 4.2699
# Epoch 116/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 1.1229 - val_loss: 3.4725
# Epoch 117/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 1.1084 - val_loss: 3.6424
# Epoch 118/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 1.0619 - val_loss: 3.0413
# Epoch 119/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 1.2695 - val_loss: 4.0452
# Epoch 120/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 1.1090 - val_loss: 3.7533

# %%
train_loss = nn_history.history['loss']
test_loss = nn_history.history['val_loss']
plt.plot(train_loss, label='Training loss')
plt.plot(test_loss, label='Testing loss')
plt.legend()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
fig = plt.subplots( figsize=(16,8))
plt.plot(LSTM_test_outputs, label = "actual")
plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
MSE = mean_squared_error(LSTM_test_outputs,nn_model.predict(LSTM_test_inputs))
R2_score = r2_score(LSTM_test_outputs,nn_model.predict(LSTM_test_inputs))
# RMSE = mean_squared_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
print('The Mean Absolute Error is: {}'.format(MAE))
print('The Mean squared Error is: {}'.format(MSE))
print('The R2 is: {}'.format(R2_score))
# print('The Mean Root mean squared error) Error is: {}'.format(RMSE))
# Out:
# The Mean Absolute Error is: 18.91322264544732
# The Mean squared Error is: 373.3232727119639
# The R2 is: -11.687139583681013

# %%
fig = plt.subplots( figsize=(18,9))
plt.plot(LSTM_training_outputs, label = "actual")
plt.plot(nn_model.predict(LSTM_training_inputs), label = "predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_training_outputs, nn_model.predict(LSTM_training_inputs))
MSE = mean_squared_error(LSTM_training_outputs,nn_model.predict(LSTM_training_inputs))
R2_score = r2_score(LSTM_training_outputs,nn_model.predict(LSTM_training_inputs))

print('The Mean Absolute Error is: {}'.format(MAE))
print('The Mean squared Error is: {}'.format(MSE))
print('The R2 is: {}'.format(R2_score))
# Out:
# The Mean Absolute Error is: 1.3455892061173866
# The Mean squared Error is: 5.769187787383533
# The R2 is: 0.9764847588429042

# %%
nn_model.get_config()
# Out:
# {'name': 'sequential_1',
#  'layers': [{'class_name': 'LSTM',
#    'config': {'name': 'lstm_1',
#     'trainable': True,
#     'batch_input_shape': (None, 1, 6),
#     'dtype': 'float32',
#     'return_sequences': False,
#     'return_state': False,
#     'go_backwards': False,
#     'stateful': False,
#     'unroll': False,
#     'units': 400,
#     'activation': 'tanh',
#     'recurrent_activation': 'sigmoid',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'recurrent_initializer': {'class_name': 'Orthogonal',
#      'config': {'gain': 1.0, 'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'unit_forget_bias': True,
#     'kernel_regularizer': None,
#     'recurrent_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'recurrent_constraint': None,
#     'bias_constraint': None,
#     'dropout': 0.0,
#     'recurrent_dropout': 0.0,
#     'implementation': 2}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.1,
#     'noise_shape': None,
#     'seed': None}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Activation',
#    'config': {'name': 'activation_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'}}]}

# %%
print(nn_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 400)               651200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 401
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 651,601
# Trainable params: 651,601
# Non-trainable params: 0
# _________________________________________________________________
# None
