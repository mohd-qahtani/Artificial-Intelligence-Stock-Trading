# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences

from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.layers import Bidirectional
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler


from sklearn import linear_model 
from sklearn.metrics import mean_absolute_error
sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('Equites_Historical_NonAdjusted_Prices.csv', usecols=['Industry Group', 'Symbol', 'Company Name', 'Date', 'Open', 'High',
       'Low', 'Close', 'Change', '% Change', 'Volume Traded','Value Traded (SAR)', 'No. of Trades'])

# %%
df.Date = pd.to_datetime(df.Date, dayfirst=True)

# %%
df.sort_values('Date',inplace=True)

# %%
df['Company Name'].unique()[65]
# Out:
# 'Saudi Advanced Industries Co.'

# %%
df['Company Name'].groupby(df['Industry Group']).value_counts()
# Out:
# Industry Group                  Company Name
# Banks                           Al Rajhi Bank                                          2722
#                                 Alinma Bank                                            2722
#                                 Arab National Bank                                     2722
#                                 Bank Albilad                                           2722
#                                 Bank Aljazira                                          2722
#                                 Banque Saudi Fransi                                    2722
#                                 Riyad Bank                                             2722
#                                 Samba Financial Group                                  2722
#                                 Saudi British Bank                                     2722
#                                 Saudi Investment Bank                                  2722
#                                 National Commercial Bank                               1262
# Capital Goods                   Al-Ahsa Development Co.                                2722
#                                 Al-Babtain Power and Telecommunication Co.             2722
#                                 Astra Industrial Group                                 2722
#                                 Middle East Specialized Cables Co.                     2722
#                                 Saudi Arabian Amiantit Co.                             2722
#                                 Saudi Cable Co.                                        2722
#                                 Saudi Ceramic Co.                                      2722
#                                 Saudi Industrial Export Co.                            2722
#                                 Saudi Vitrified Clay Pipes Co.                         2722
#                                 Abdullah A. M. Al-Khodari Sons Co.                     2268
#                                 Mohammad Al Mojil Group                                2087
#                                 Bawan Co.                                              1482
#                                 Electrical Industries Co.                              1245
# Commercial & Professional Svc   Saudi Printing and Packaging Co.                       2722
#                                 Saudi Airlines Catering Co.                            1839
#                                 Maharah Human Resources Co.                             112
# Consumer Durables & Apparel     Al Abdullatif Industrial Investment Co.                2722
#                                 Fitaihi Holding Group                                  2722
#                                 Saudi Industrial Development Co.                       2722
#                                                                                        ...
# Real Estate Mgmt & Dev't        Emaar The Economic City                                2722
#                                 Jabal Omar Development Co.                             2722
#                                 Makkah Construction and Development Co.                2722
#                                 Red Sea International Co.                              2722
#                                 Saudi Real Estate Co.                                  2722
#                                 Taiba Investments Co.                                  2722
#                                 Knowledge Economic City                                2315
#                                 Alandalus Property Co.                                  968
#                                 Arabian Centres Co.                                     126
# Retailing                       Fawaz Abdulaziz Alhokair Co.                           2722
#                                 Jarir Marketing Co.                                    2722
#                                 Saudi Automotive Services Co.                          2722
#                                 Al Hassan Ghazi Ibrahim Shaker Co.                     2375
#                                 United Electronics Co.                                 1981
#                                 Saudi Company for Hardware                             1134
#                                 Abdullah Saad Mohammed Abo Moati for Bookstores Co.     686
# Software & Services             Al Moammar Information Systems Co.                      146
# Tadawul All Share Index (TASI)  Alawwal Bank                                           2610
# Telecommunication Services      Etihad Etisalat Co.                                    2722
#                                 Mobile Telecommunication Company Saudi Arabia          2722
#                                 Saudi Telecom Co.                                      2722
#                                 Etihad Atheeb Telecommunication Co.                    2667
#                                 Saudi Integrated Telecom Company                        399
# Transportation                  Batic Investments and Logistics Co.                    2722
#                                 Saudi Industrial Services Co.                          2722
#                                 Saudi Public Transport Co.                             2722
#                                 United International Transportation Co.                2722
#                                 Saudi Ground Services Co.                              1102
# Utilities                       National Gas and Industrialization Co.                 2722
#                                 Saudi Electricity Co.                                  2722
# Name: Company Name, Length: 205, dtype: int64

# %%
df[df['Industry Group'] == 'Banks']
# Out:
#       Industry Group  Symbol              Company Name       Date   Open  \
# 21064          Banks    1090     Samba Financial Group 2009-01-03  50.75
# 26503          Banks    1140              Bank Albilad 2009-01-03  28.10
# 6059           Banks    1030     Saudi Investment Bank 2009-01-03  16.95
# 2121           Banks    1010                Riyad Bank 2009-01-03  21.00
# 15620          Banks    1060        Saudi British Bank 2009-01-03  53.75
# 12898          Banks    1050       Banque Saudi Fransi 2009-01-03  44.60
# 23781          Banks    1120             Al Rajhi Bank 2009-01-03  57.00
# 27725          Banks    1150               Alinma Bank 2009-01-03  11.20
# 4843           Banks    1020             Bank Aljazira 2009-01-03  15.10
# 18343          Banks    1080        Arab National Bank 2009-01-03  31.00
# 12909          Banks    1050       Banque Saudi Fransi 2009-01-04  46.90
# 15631          Banks    1060        Saudi British Bank 2009-01-04  59.00
# 23776          Banks    1120             Al Rajhi Bank 2009-01-04  58.50
# 18353          Banks    1080        Arab National Bank 2009-01-04  34.20
# 2123           Banks    1010                Riyad Bank 2009-01-04  21.70
# 26498          Banks    1140              Bank Albilad 2009-01-04  28.80
# 27719          Banks    1150               Alinma Bank 2009-01-04  11.50
# 21075          Banks    1090     Samba Financial Group 2009-01-04  50.50
# 4845           Banks    1020             Bank Aljazira 2009-01-04  15.95
# 6061           Banks    1030     Saudi Investment Bank 2009-01-04  17.40
# 2133           Banks    1010                Riyad Bank 2009-01-05  21.45
# 21059          Banks    1090     Samba Financial Group 2009-01-05  51.00
# 27721          Banks    1150               Alinma Bank 2009-01-05  11.35
# 26499          Banks    1140              Bank Albilad 2009-01-05  28.30
# 6071           Banks    1030     Saudi Investment Bank 2009-01-05  17.45
# 18339          Banks    1080        Arab National Bank 2009-01-05  33.80
# 4855           Banks    1020             Bank Aljazira 2009-01-05  15.90
# 15616          Banks    1060        Saudi British Bank 2009-01-05  59.00
# 12894          Banks    1050       Banque Saudi Fransi 2009-01-05  47.40
# 23777          Banks    1120             Al Rajhi Bank 2009-01-05  58.50
# ...              ...     ...                       ...        ...    ...
# 10805          Banks    1050       Banque Saudi Fransi 2019-11-26  33.90
# 29814          Banks    1150               Alinma Bank 2019-11-26  22.86
# 29860          Banks    1180  National Commercial Bank 2019-11-26  47.20
# 18967          Banks    1090     Samba Financial Group 2019-11-26  30.00
# 16249          Banks    1080        Arab National Bank 2019-11-26  25.50
# 21682          Banks    1120             Al Rajhi Bank 2019-11-26  64.50
# 13527          Banks    1060        Saudi British Bank 2019-11-26  36.40
# 2751           Banks    1020             Bank Aljazira 2019-11-26  13.80
# 2747           Banks    1020             Bank Aljazira 2019-11-27  13.74
# 29815          Banks    1150               Alinma Bank 2019-11-27  22.82
# 29861          Banks    1180  National Commercial Bank 2019-11-27  45.60
# 13523          Banks    1060        Saudi British Bank 2019-11-27  37.05
# 25             Banks    1010                Riyad Bank 2019-11-27  21.76
# 18968          Banks    1090     Samba Financial Group 2019-11-27  29.60
# 16245          Banks    1080        Arab National Bank 2019-11-27  25.40
# 21683          Banks    1120             Al Rajhi Bank 2019-11-27  63.00
# 10801          Banks    1050       Banque Saudi Fransi 2019-11-27  33.55
# 8156           Banks    1030     Saudi Investment Bank 2019-11-27  16.20
# 24405          Banks    1140              Bank Albilad 2019-11-27  25.80
# 26             Banks    1010                Riyad Bank 2019-11-28  21.70
# 29816          Banks    1150               Alinma Bank 2019-11-28  22.60
# 29862          Banks    1180  National Commercial Bank 2019-11-28  45.25
# 13524          Banks    1060        Saudi British Bank 2019-11-28  35.65
# 21684          Banks    1120             Al Rajhi Bank 2019-11-28  62.30
# 18969          Banks    1090     Samba Financial Group 2019-11-28  29.15
# 16246          Banks    1080        Arab National Bank 2019-11-28  25.10
# 2748           Banks    1020             Bank Aljazira 2019-11-28  13.70
# 8157           Banks    1030     Saudi Investment Bank 2019-11-28  16.12
# 10802          Banks    1050       Banque Saudi Fransi 2019-11-28  33.60
# 24406          Banks    1140              Bank Albilad 2019-11-28  25.55
#
#         High    Low  Close  Change  % Change  Volume Traded  \
# 21064  52.00  50.50  50.50   -0.75     -1.46         455859
# 26503  29.10  28.10  28.30    0.30      1.07         606031
# 6059   17.75  16.95  17.20    0.65      3.92         160643
# 2121   21.85  21.00  21.75    0.55      2.59         589847
# 15620  57.50  53.75  56.50    2.50      4.62          25475
# 12898  47.00  44.60  47.00    1.90      4.21         173113
# 23781  59.50  57.00  58.50    2.50      4.46        3118489
# 27725  11.65  11.20  11.55    0.45      4.05       88413603
# 4843   15.95  15.10  15.95    0.90      5.98        1600168
# 18343  34.30  31.00  34.20    3.00      9.61         333363
# 12909  47.70  46.30  47.60    0.60      1.27          54976
# 15631  59.00  56.75  59.00    2.50      4.42         109403
# 23776  59.25  58.00  58.50    0.00      0.00        2061488
# 18353  34.20  33.60  33.90   -0.30     -0.87         111997
# 2123   21.70  21.30  21.65   -0.10     -0.45         417290
# 26498  28.80  28.10  28.30    0.00      0.00         318159
# 27719  11.55  11.30  11.40   -0.15     -1.29       41653825
# 21075  51.50  49.20  51.00    0.50      0.99         499052
# 4845   16.00  15.75  16.00    0.05      0.31         620236
# 6061   17.65  17.10  17.50    0.30      1.74         123197
# 2133   21.80  21.45  21.80    0.15      0.69         708922
# 21059  52.75  50.00  52.00    1.00      1.96         590313
# 27721  11.75  11.30  11.65    0.25      2.19      115906810
# 26499  28.60  28.20  28.50    0.20      0.70         710615
# 6071   18.00  17.40  18.00    0.50      2.85         227891
# 18339  34.30  33.70  34.20    0.30      0.88         314626
# 4855   16.30  15.85  16.15    0.15      0.93         850707
# 15616  60.00  58.00  60.00    1.00      1.69          32137
# 12894  49.60  47.00  49.40    1.80      3.78         331910
# 23777  60.75  58.25  60.00    1.50      2.56        2546478
# ...      ...    ...    ...     ...       ...            ...
# 10805  34.15  33.25  33.25   -0.50     -1.48        1705692
# 29814  22.94  22.76  22.94    0.06      0.26        8692766
# 29860  47.20  45.25  45.25   -1.90     -4.03        3471303
# 18967  30.10  29.25  29.25   -0.90     -2.99        3733599
# 16249  25.50  24.56  25.40    0.05      0.20       38496434
# 21682  64.70  62.40  62.40   -2.10     -3.26       10942758
# 13527  37.05  35.30  37.05    1.05      2.92       24296158
# 2751   13.80  13.68  13.80    0.00      0.00        4077882
# 2747   13.76  13.66  13.70   -0.10     -0.72        1785640
# 29815  22.96  22.54  22.58   -0.36     -1.57        6355979
# 29861  45.70  45.00  45.45    0.20      0.44         997797
# 13523  37.05  35.35  35.80   -1.25     -3.37        2188102
# 25     21.90  21.70  21.72    0.14      0.65        1637540
# 18968  29.80  29.10  29.35    0.10      0.34         941829
# 16245  25.45  24.96  25.30   -0.10     -0.39        2808634
# 21683  63.60  61.70  61.80   -0.60     -0.96        6982091
# 10801  34.00  33.55  34.00    0.75      2.26         551020
# 8156   16.22  16.20  16.22    0.00      0.00          10703
# 24405  26.20  25.65  25.75    0.00      0.00         483048
# 26     22.18  21.66  22.00    0.28      1.29        1693876
# 29816  22.84  22.56  22.80    0.22      0.97        6644812
# 29862  46.35  45.25  46.00    0.55      1.21         918311
# 13524  35.80  34.10  34.10   -1.70     -4.75        1486330
# 21684  63.10  61.90  62.20    0.40      0.65        5262266
# 18969  29.25  28.55  29.15   -0.20     -0.68        1495836
# 16246  25.85  25.10  25.50    0.20      0.79        6260315
# 2748   13.72  13.62  13.62   -0.08     -0.58        1460270
# 8157   16.20  16.08  16.20   -0.02     -0.12         131084
# 10802  33.85  33.35  33.50   -0.50     -1.47         610294
# 24406  25.90  25.50  25.80    0.05      0.19         337363
#
#        Value Traded (SAR)  No. of Trades
# 21064        2.334883e+07            678
# 26503        1.736057e+07            612
# 6059         2.782922e+06            111
# 2121         1.274388e+07            517
# 15620        1.436504e+06             93
# 12898        8.040055e+06            185
# 23781        1.820464e+08           2865
# 27725        1.014294e+09           9448
# 4843         2.476491e+07            718
# 18343        1.124767e+07            370
# 12909        2.590814e+06            109
# 15631        6.360746e+06            100
# 23776        1.206332e+08           1728
# 18353        3.798586e+06            109
# 2123         8.990776e+06            409
# 26498        9.002257e+06            505
# 27719        4.756178e+08           6089
# 21075        2.532698e+07            631
# 4845         9.883137e+06            393
# 6061         2.152199e+06            129
# 2133         1.536708e+07            526
# 21059        3.040180e+07            552
# 27721        1.345981e+09           9801
# 26499        2.018271e+07            726
# 6071         4.033047e+06            118
# 18339        1.068190e+07            224
# 4855         1.370087e+07            545
# 15616        1.912713e+06             41
# 12894        1.613006e+07            199
# 23777        1.522310e+08           2285
# ...                   ...            ...
# 10805        5.686627e+07            586
# 29814        1.987630e+08           4066
# 29860        1.578093e+08           1196
# 18967        1.099714e+08           1108
# 16249        9.749139e+08           6005
# 21682        6.913918e+08           6510
# 13527        8.971989e+08           2936
# 2751         5.614679e+07            970
# 2747         2.448475e+07            784
# 29815        1.450239e+08           4536
# 29861        4.513672e+07           1401
# 13523        7.855653e+07           2070
# 25           3.568464e+07           1175
# 18968        2.773024e+07           1078
# 16245        7.080241e+07           1336
# 21683        4.395077e+08           6031
# 10801        1.868539e+07            459
# 8156         1.734346e+05             23
# 24405        1.248180e+07           1048
# 26           3.671371e+07            852
# 29816        1.507655e+08           4950
# 29862        4.217433e+07            989
# 13524        5.115902e+07           1369
# 21684        3.284859e+08           4586
# 18969        4.299681e+07           1233
# 16246        1.582016e+08            924
# 2748         1.999186e+07            815
# 8157         1.988629e+06             35
# 10802        2.010179e+07            522
# 24406        8.675895e+06            681
#
# [28482 rows x 13 columns]

# %%
Riyad_Bank = df[df['Company Name']== 'Saudi Printing and Packaging Co.']

# %%
Riyadhb_for_model = Riyad_Bank[['Date','Open', 'High', 'Low',
       'Close', 'Change', '% Change']]

# %%
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaled = scaler.fit_transform(Riyad_Bank[['Open', 'High', 'Low',
#        'Close', 'Change']])

# %%
# scaled_df = pd.DataFrame()

# %%
Riyadhb_for_model
# Out:
#              Date   Open   High    Low  Close  Change  % Change
# 294860 2009-01-03  13.95  14.35  13.95  14.35    0.35      2.50
# 294848 2009-01-04  14.40  15.20  14.20  15.05    0.70      4.87
# 294858 2009-01-05  15.05  15.50  14.90  15.35    0.30      1.99
# 294859 2009-01-06  15.35  15.75  15.25  15.55    0.20      1.30
# 294857 2009-01-07  15.55  15.65  15.15  15.60    0.05      0.32
# 294866 2009-01-10  15.35  15.40  14.50  15.25   -0.35     -2.24
# 294864 2009-01-11  16.75  16.75  16.75  16.75    1.50      9.83
# 294865 2009-01-12  17.50  18.35  17.20  17.60    0.85      5.07
# 294862 2009-01-13  17.40  17.55  17.20  17.40   -0.20     -1.13
# 294872 2009-01-14  17.20  17.35  17.05  17.10   -0.30     -1.72
# 294861 2009-01-17  17.00  17.10  15.60  16.00   -1.10     -6.43
# 294871 2009-01-18  16.00  16.75  16.00  16.65    0.65      4.06
# 294868 2009-01-19  16.60  16.80  16.45  16.75    0.10      0.60
# 294751 2009-01-20  16.25  17.50  15.50  17.50    0.75      4.47
# 294867 2009-01-21  17.00  18.80  16.95  18.25    0.75      4.28
# 294749 2009-01-24  18.70  19.95  18.55  19.85    1.60      8.76
# 294874 2009-01-25  19.90  20.20  19.50  20.10    0.25      1.25
# 294747 2009-01-26  20.00  20.05  19.70  20.05   -0.05     -0.24
# 294757 2009-01-27  19.95  20.20  19.30  19.30   -0.75     -3.74
# 294873 2009-01-28  19.30  19.65  18.75  18.80   -0.50     -2.59
# 294756 2009-01-31  18.70  19.25  18.70  19.25    0.45      2.39
# 294753 2009-02-01  19.35  19.40  19.00  19.10   -0.15     -0.77
# 294754 2009-02-02  19.10  19.10  18.75  19.00   -0.10     -0.52
# 294752 2009-02-03  18.90  19.55  18.90  19.50    0.50      2.63
# 294762 2009-02-04  19.75  20.05  19.35  20.00    0.50      2.56
# 294760 2009-02-07  20.45  21.10  20.45  20.85    0.85      4.25
# 294761 2009-02-08  20.80  20.95  20.30  20.80   -0.05     -0.23
# 294758 2009-02-09  20.75  21.00  20.75  21.00    0.20      0.96
# 294768 2009-02-10  21.00  21.40  20.60  20.80   -0.20     -0.95
# 294769 2009-02-11  20.10  20.75  20.00  20.45   -0.35     -1.68
# ...           ...    ...    ...    ...    ...     ...       ...
# 292733 2019-10-20  12.00  12.08  11.86  11.94    0.14      1.19
# 292732 2019-10-21  12.00  12.00  11.80  11.86   -0.08     -0.67
# 292731 2019-10-22  11.86  12.00  11.82  11.82   -0.04     -0.34
# 292740 2019-10-23  11.86  12.00  11.86  11.92    0.10      0.85
# 292739 2019-10-24  11.92  11.98  11.90  11.98    0.06      0.50
# 292738 2019-10-27  12.00  12.72  11.98  12.36    0.38      3.17
# 292737 2019-10-28  12.32  12.44  12.00  12.02   -0.34     -2.75
# 292736 2019-10-29  11.98  11.98  11.66  11.66   -0.36     -3.00
# 292746 2019-10-30  11.88  11.92  11.68  11.76    0.10      0.86
# 292744 2019-10-31  12.20  12.88  12.20  12.22    0.46      3.91
# 292745 2019-11-03  12.02  12.10  11.80  11.98   -0.24     -1.96
# 292743 2019-11-04  12.10  12.38  12.06  12.08    0.10      0.83
# 292742 2019-11-05  12.10  12.14  11.98  12.04   -0.04     -0.33
# 292741 2019-11-06  12.10  12.10  11.98  12.00   -0.04     -0.33
# 292752 2019-11-07  11.98  12.18  11.96  11.96   -0.04     -0.33
# 292751 2019-11-10  12.00  12.04  12.00  12.00    0.04      0.33
# 292750 2019-11-11  12.02  12.04  11.96  12.00    0.00      0.00
# 292749 2019-11-12  12.02  12.08  12.00  12.02    0.02      0.17
# 292748 2019-11-13  12.04  12.06  11.90  11.90   -0.12     -1.00
# 292747 2019-11-14  11.84  11.86  11.74  11.74   -0.16     -1.34
# 292757 2019-11-17  11.68  11.70  11.50  11.58   -0.16     -1.36
# 292756 2019-11-18  11.60  11.64  11.56  11.62    0.04      0.35
# 292755 2019-11-19  11.66  12.22  11.66  11.90    0.28      2.41
# 292754 2019-11-20  11.84  11.90  11.70  11.72   -0.18     -1.51
# 292753 2019-11-21  11.70  11.78  11.68  11.74    0.02      0.17
# 292762 2019-11-24  11.70  11.70  11.58  11.62   -0.12     -1.02
# 292761 2019-11-25  11.60  11.62  11.54  11.54   -0.08     -0.69
# 292760 2019-11-26  11.54  11.64  11.52  11.52   -0.02     -0.17
# 292759 2019-11-27  11.60  11.62  11.52  11.54    0.02      0.17
# 292758 2019-11-28  11.54  11.62  11.54  11.54    0.00      0.00
#
# [2722 rows x 7 columns]

# %%
Riyadhb_for_model.reset_index(inplace=True)

# %%
window_len = 1

#Create a data point (i.e. a date) which splits the training and testing set
split_date = list(Riyadhb_for_model["Date"][-(227):])[0]

# %%
split_date
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
training_set, test_set = Riyadhb_for_model[Riyadhb_for_model['Date'] < split_date], Riyadhb_for_model[Riyadhb_for_model['Date'] >= split_date]

# %%
training_set.shape
# Out:
# (2495, 8)

# %%
test_set.shape
# Out:
# (227, 8)

# %%
training_set.set_index('Date',inplace=True)

# %%
test_set.set_index('Date',inplace=True)

# %%
# training_target = training_set.pop('Close')

# %%
# testing_target = test_set.pop('Close')

# %%
training_set = training_set.drop(['index'], 1)
test_set = test_set.drop(['index'], 1)

# %%
training = training_set.values

# %%
testing = test_set.values

# %%
testing[0]
# Out:
# array([16.18, 16.3 , 16.  , 16.3 ,  0.12,  0.74])

# %%
test_set[0:1]
# Out:
#              Open  High   Low  Close  Change  % Change
# Date
# 2019-01-01  16.18  16.3  16.0   16.3    0.12      0.74

# %%
training_set.tail(10)
# Out:
#              Open   High    Low  Close  Change  % Change
# Date
# 2018-12-18  17.20  17.34  17.14  17.18   -0.08     -0.46
# 2018-12-19  17.14  17.48  16.84  16.84   -0.34     -1.98
# 2018-12-20  16.86  17.00  16.10  16.30   -0.54     -3.21
# 2018-12-23  16.00  16.16  15.60  16.10   -0.20     -1.23
# 2018-12-24  16.10  16.70  16.10  16.58    0.48      2.98
# 2018-12-25  16.50  16.50  16.16  16.22   -0.36     -2.17
# 2018-12-26  16.50  16.52  16.20  16.24    0.02      0.12
# 2018-12-27  16.40  16.52  16.18  16.18   -0.06     -0.37
# 2018-12-30  16.24  16.40  16.22  16.34    0.16      0.99
# 2018-12-31  16.34  16.34  16.18  16.18   -0.16     -0.98

# %%
LSTM_training_inputs = []
for i in range(len(training)-window_len):
    temp_set = training[i:(i+window_len)].copy()
    
    LSTM_training_inputs.append(temp_set)
LSTM_training_outputs = training_set['Close'][window_len:].values
# LSTM_training_outputs = scaler.transform(LSTM_training_outputs)
# LSTM_training_outputs = np.reshape(LSTM_training_outputs, (len(LSTM_training_outputs),1,1))


LSTM_training_inputs = np.array(LSTM_training_inputs)
# LSTM_training_inputs = scaler.fit_transform(LSTM_training_inputs)
# LSTM_training_inputs = np.reshape(LSTM_training_inputs,(len(LSTM_training_inputs),window_len,1))

#Create windows for testing
LSTM_test_inputs = []
for i in range(len(testing)-window_len):
    temp_set1 = testing[i:(i+window_len)].copy()
    
    
    LSTM_test_inputs.append(temp_set1)
LSTM_test_outputs = test_set['Close'][window_len:].values
# LSTM_test_outputs = scaler.transform(LSTM_test_outputs)
 
LSTM_test_inputs = np.array(LSTM_test_inputs)
# LSTM_test_inputs = scaler.transform(LSTM_test_inputs)
# LSTM_test_inputs = np.reshape(LSTM_test_inputs,(len(LSTM_test_inputs),window_len,1))

# %%
LSTM_test_inputs
# Out:
# array([[[16.18, 16.3 , 16.  , 16.3 ,  0.12,  0.74]],
#
#        [[16.24, 16.24, 16.08, 16.14, -0.16, -0.98]],
#
#        [[16.2 , 16.48, 16.16, 16.26,  0.12,  0.74]],
#
#        ...,
#
#        [[11.6 , 11.62, 11.54, 11.54, -0.08, -0.69]],
#
#        [[11.54, 11.64, 11.52, 11.52, -0.02, -0.17]],
#
#        [[11.6 , 11.62, 11.52, 11.54,  0.02,  0.17]]])

# %%
LSTM_training_inputs.shape
# Out:
# (2494, 1, 6)

# %%
nn_model.reset_states()
nn_model.reset_metrics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c2217cfdbcf3> in <module>
# ----> 1 nn_model.reset_states()
#       2 nn_model.reset_metrics()
#
# NameError: name 'nn_model' is not defined

# %%
def build_model(inputs, output_size, neurons, activ_func="relu",
                dropout=0.10, loss="mae", optimizer="adam"):
    
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
nn_model = build_model(LSTM_training_inputs, output_size=1, neurons = 400)

nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                            epochs=120, batch_size=200, verbose=1,validation_split= 0.2)
# Out:
# Train on 1995 samples, validate on 499 samples
# Epoch 1/120
# 1995/1995 [==============================] - 1s 306us/step - loss: 19.0538 - val_loss: 13.8159
# Epoch 2/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 14.4246 - val_loss: 9.1959
# Epoch 3/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 9.6108 - val_loss: 4.1919
# Epoch 4/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 5.3986 - val_loss: 1.2308
# Epoch 5/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 4.4139 - val_loss: 2.8690
# Epoch 6/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 4.3573 - val_loss: 2.3174
# Epoch 7/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 3.8901 - val_loss: 1.1021
# Epoch 8/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 3.4093 - val_loss: 0.7260
# Epoch 9/120
# 1995/1995 [==============================] - 0s 66us/step - loss: 2.8327 - val_loss: 0.5278
# Epoch 10/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 2.2339 - val_loss: 0.4677
# Epoch 11/120
# 1995/1995 [==============================] - 0s 68us/step - loss: 1.7660 - val_loss: 0.5275
# Epoch 12/120
# 1995/1995 [==============================] - 0s 65us/step - loss: 1.5122 - val_loss: 0.6185
# Epoch 13/120
# 1995/1995 [==============================] - 0s 66us/step - loss: 1.3707 - val_loss: 0.8195
# Epoch 14/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 1.3010 - val_loss: 0.4399
# Epoch 15/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 1.2776 - val_loss: 0.8361
# Epoch 16/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 1.2257 - val_loss: 0.6755
# Epoch 17/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 1.1629 - val_loss: 0.4981
# Epoch 18/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 1.1266 - val_loss: 0.5145
# Epoch 19/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 1.0998 - val_loss: 0.6541
# Epoch 20/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 1.0729 - val_loss: 0.4076
# Epoch 21/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 1.0446 - val_loss: 0.4573
# Epoch 22/120
# 1995/1995 [==============================] - 0s 66us/step - loss: 1.0167 - val_loss: 0.7104
# Epoch 23/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 0.9683 - val_loss: 0.4801
# Epoch 24/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.9408 - val_loss: 0.4187
# Epoch 25/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 0.9032 - val_loss: 0.4544
# Epoch 26/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 0.8732 - val_loss: 0.4891
# Epoch 27/120
# 1995/1995 [==============================] - 0s 68us/step - loss: 0.8707 - val_loss: 0.7873
# Epoch 28/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 0.8781 - val_loss: 0.7224
# Epoch 29/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.8461 - val_loss: 0.5710
# Epoch 30/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.8328 - val_loss: 0.6862
# Epoch 31/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.8175 - val_loss: 0.5453
# Epoch 32/120
# 1995/1995 [==============================] - 0s 69us/step - loss: 0.7844 - val_loss: 0.3976
# Epoch 33/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 0.7532 - val_loss: 0.3411
# Epoch 34/120
# 1995/1995 [==============================] - 0s 68us/step - loss: 0.7369 - val_loss: 0.3203
# Epoch 35/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 0.7622 - val_loss: 0.3292
# Epoch 36/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 0.7365 - val_loss: 0.3172
# Epoch 37/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 0.6967 - val_loss: 0.3178
# Epoch 38/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 0.6857 - val_loss: 0.4649
# Epoch 39/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 0.6712 - val_loss: 0.4295
# Epoch 40/120
# 1995/1995 [==============================] - 0s 68us/step - loss: 0.6653 - val_loss: 0.3807
# Epoch 41/120
# 1995/1995 [==============================] - 0s 69us/step - loss: 0.6430 - val_loss: 0.4407
# Epoch 42/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.6700 - val_loss: 0.4297
# Epoch 43/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.6823 - val_loss: 0.3078
# Epoch 44/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.6491 - val_loss: 0.3393
# Epoch 45/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.6321 - val_loss: 0.5059
# Epoch 46/120
# 1995/1995 [==============================] - 0s 68us/step - loss: 0.6550 - val_loss: 0.3989
# Epoch 47/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.7077 - val_loss: 0.3932
# Epoch 48/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 0.6217 - val_loss: 0.3232
# Epoch 49/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 0.5988 - val_loss: 0.3673
# Epoch 50/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 0.6685 - val_loss: 0.3375
# Epoch 51/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 0.6186 - val_loss: 0.3222
# Epoch 52/120
# 1995/1995 [==============================] - 0s 69us/step - loss: 0.5989 - val_loss: 0.3039
# Epoch 53/120
# 1995/1995 [==============================] - 0s 68us/step - loss: 0.6029 - val_loss: 0.4476
# Epoch 54/120
# 1995/1995 [==============================] - 0s 69us/step - loss: 0.6161 - val_loss: 0.3184
# Epoch 55/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 0.6093 - val_loss: 0.3073
# Epoch 56/120
# 1995/1995 [==============================] - 0s 67us/step - loss: 0.5977 - val_loss: 0.4519
# Epoch 57/120
# 1995/1995 [==============================] - 0s 69us/step - loss: 0.6114 - val_loss: 0.3604
# Epoch 58/120
# 1995/1995 [==============================] - 0s 70us/step - loss: 0.5758 - val_loss: 0.3273
# Epoch 59/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.5864 - val_loss: 0.3080
# Epoch 60/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.5870 - val_loss: 0.3074
# Epoch 61/120
# 1995/1995 [==============================] - 0s 71us/step - loss: 0.6037 - val_loss: 0.4540
# Epoch 62/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 0.5814 - val_loss: 0.3475
# Epoch 63/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 0.5570 - val_loss: 0.3570
# Epoch 64/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5534 - val_loss: 0.3209
# Epoch 65/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5628 - val_loss: 0.3185
# Epoch 66/120
# 1995/1995 [==============================] - 0s 72us/step - loss: 0.5820 - val_loss: 0.3231
# Epoch 67/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5972 - val_loss: 0.3308
# Epoch 68/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 0.6190 - val_loss: 0.5139
# Epoch 69/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 0.6273 - val_loss: 0.3515
# Epoch 70/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.6093 - val_loss: 0.3727
# Epoch 71/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.6561 - val_loss: 0.5300
# Epoch 72/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.6234 - val_loss: 0.3680
# Epoch 73/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5658 - val_loss: 0.2978
# Epoch 74/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.5355 - val_loss: 0.3222
# Epoch 75/120
# 1995/1995 [==============================] - 0s 84us/step - loss: 0.5587 - val_loss: 0.3433
# Epoch 76/120
# 1995/1995 [==============================] - 0s 82us/step - loss: 0.5442 - val_loss: 0.3096
# Epoch 77/120
# 1995/1995 [==============================] - 0s 82us/step - loss: 0.5422 - val_loss: 0.3441
# Epoch 78/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 0.5678 - val_loss: 0.2940
# Epoch 79/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5807 - val_loss: 0.3218
# Epoch 80/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5608 - val_loss: 0.3277
# Epoch 81/120
# 1995/1995 [==============================] - 0s 80us/step - loss: 0.5623 - val_loss: 0.3405
# Epoch 82/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.5584 - val_loss: 0.3794
# Epoch 83/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.5768 - val_loss: 0.3573
# Epoch 84/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5759 - val_loss: 0.3004
# Epoch 85/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.5390 - val_loss: 0.3873
# Epoch 86/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.5307 - val_loss: 0.3026
# Epoch 87/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5442 - val_loss: 0.3190
# Epoch 88/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.5605 - val_loss: 0.3485
# Epoch 89/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 0.5523 - val_loss: 0.3559
# Epoch 90/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5573 - val_loss: 0.3691
# Epoch 91/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5608 - val_loss: 0.3263
# Epoch 92/120
# 1995/1995 [==============================] - 0s 78us/step - loss: 0.5585 - val_loss: 0.4030
# Epoch 93/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 0.5486 - val_loss: 0.3019
# Epoch 94/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 0.5355 - val_loss: 0.2927
# Epoch 95/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5761 - val_loss: 0.3583
# Epoch 96/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5302 - val_loss: 0.3492
# Epoch 97/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5532 - val_loss: 0.3558
# Epoch 98/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 0.5719 - val_loss: 0.2894
# Epoch 99/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 0.5723 - val_loss: 0.4555
# Epoch 100/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 0.5762 - val_loss: 0.5242
# Epoch 101/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5816 - val_loss: 0.2915
# Epoch 102/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 0.5384 - val_loss: 0.2959
# Epoch 103/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5855 - val_loss: 0.4444
# Epoch 104/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5662 - val_loss: 0.2992
# Epoch 105/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5634 - val_loss: 0.3014
# Epoch 106/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5396 - val_loss: 0.3015
# Epoch 107/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5221 - val_loss: 0.3099
# Epoch 108/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 0.5498 - val_loss: 0.3320
# Epoch 109/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5534 - val_loss: 0.2992
# Epoch 110/120
# 1995/1995 [==============================] - 0s 80us/step - loss: 0.5681 - val_loss: 0.3381
# Epoch 111/120
# 1995/1995 [==============================] - 0s 79us/step - loss: 0.5901 - val_loss: 0.3525
# Epoch 112/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 0.5791 - val_loss: 0.4455
# Epoch 113/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 0.5819 - val_loss: 0.3411
# Epoch 114/120
# 1995/1995 [==============================] - 0s 76us/step - loss: 0.5841 - val_loss: 0.3006
# Epoch 115/120
# 1995/1995 [==============================] - 0s 74us/step - loss: 0.5495 - val_loss: 0.3150
# Epoch 116/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 0.5549 - val_loss: 0.3182
# Epoch 117/120
# 1995/1995 [==============================] - 0s 73us/step - loss: 0.5574 - val_loss: 0.3352
# Epoch 118/120
# 1995/1995 [==============================] - 0s 75us/step - loss: 0.5339 - val_loss: 0.3655
# Epoch 119/120
# 1995/1995 [==============================] - 0s 77us/step - loss: 0.5471 - val_loss: 0.3033
# Epoch 120/120
# 1995/1995 [==============================] - 0s 85us/step - loss: 0.5307 - val_loss: 0.2960

# %%
train_loss = nn_history.history['loss']
test_loss = nn_history.history['val_loss']
plt.plot(train_loss, label='Training loss')
plt.plot(test_loss, label='Testing loss')
plt.legend()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
fig = plt.subplots( figsize=(16,8))
plt.plot(LSTM_test_outputs, label = "actual")
plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
MSE = mean_squared_error(LSTM_test_outputs,nn_model.predict(LSTM_test_inputs))
R2_score = r2_score(LSTM_test_outputs,nn_model.predict(LSTM_test_inputs))
# RMSE = mean_squared_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
print('The Mean Absolute Error is: {}'.format(MAE))
print('The Mean squared Error is: {}'.format(MSE))
print('The R2 is: {}'.format(R2_score))
# print('The Mean Root mean squared error) Error is: {}'.format(RMSE))
# Out:
# The Mean Absolute Error is: 0.14521725949987907
# The Mean squared Error is: 0.039330635360219315
# The R2 is: 0.9861846587042247

# %%
fig = plt.subplots( figsize=(18,9))
plt.plot(LSTM_training_outputs, label = "actual")
plt.plot(nn_model.predict(LSTM_training_inputs), label = "predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_training_outputs, nn_model.predict(LSTM_training_inputs))
MSE = mean_squared_error(LSTM_training_outputs,nn_model.predict(LSTM_training_inputs))
R2_score = r2_score(LSTM_training_outputs,nn_model.predict(LSTM_training_inputs))

print('The Mean Absolute Error is: {}'.format(MAE))
print('The Mean squared Error is: {}'.format(MSE))
print('The R2 is: {}'.format(R2_score))
# Out:
# The Mean Absolute Error is: 0.38129696712172695
# The Mean squared Error is: 0.36548065378055467
# The R2 is: 0.9917827315866927

# %%
nn_model.get_config()
# Out:
# {'name': 'sequential_1',
#  'layers': [{'class_name': 'LSTM',
#    'config': {'name': 'lstm_1',
#     'trainable': True,
#     'batch_input_shape': (None, 1, 6),
#     'dtype': 'float32',
#     'return_sequences': False,
#     'return_state': False,
#     'go_backwards': False,
#     'stateful': False,
#     'unroll': False,
#     'units': 400,
#     'activation': 'tanh',
#     'recurrent_activation': 'sigmoid',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'recurrent_initializer': {'class_name': 'Orthogonal',
#      'config': {'gain': 1.0, 'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'unit_forget_bias': True,
#     'kernel_regularizer': None,
#     'recurrent_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'recurrent_constraint': None,
#     'bias_constraint': None,
#     'dropout': 0.0,
#     'recurrent_dropout': 0.0,
#     'implementation': 2}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.1,
#     'noise_shape': None,
#     'seed': None}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Activation',
#    'config': {'name': 'activation_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'}}]}

# %%
print(nn_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 400)               651200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 401
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 651,601
# Trainable params: 651,601
# Non-trainable params: 0
# _________________________________________________________________
# None
